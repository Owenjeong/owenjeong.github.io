# %% [markdown]
# ## News Sentiment Analysis
#
# In this article, I will analyze an interactive stock sentiment treemap for S&P500.
#
# You are able to see this treemap in this link.

# %%
# https://medium.datadriveninvestor.com/build-an-interactive-stock-sentiment-heatmap-for-your-portfolio-a467c45e37a2
# libraries for webscraping, parsing and getting stock data
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import yfinance as yf

# for plotting and data manipulation
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly
import plotly.express as px

# NLTK VADER for sentiment analysis
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import requests as r
import io

# %%
tickers_dict = {'AMZN': 5, 'TSLA': 1, 'GOOG': 3, 'META': 3, 'KO': 10, 'PEP': 5,  # amazon, tesla, google, meta, coke, pepsi
                'BA': 5, 'XOM': 5, 'CVX': 4, 'UNH': 1, 'JNJ': 3, 'JPM': 3, # boeing, exxon mobil, chevron, united health, johnson&johnson, jp morgan
                'BAC': 5, 'C': 5, 'SPG': 10, 'AAPL': 6, 'MSFT': 5, 'WMT': 6, # bank of america, citigroup, simon property group, apple, microsoft, walmart
                'LMT': 2, 'PFE': 10, 'MMM': 3, 'CRWD': 3, 'WBD': 20, 'DIS': 8, # lockheed martin, pfizer, 3M, crowdstrike, warner bros, disney
                'AIG': 5, 'BRK-B': 4, 'DDOG': 3, 'SLB': 16, 'SONY': 5, 'PLD': 5, # american international group, berkshire hathaway, datadog, schlumberger, sony, prologis
                'INT': 16, 'AMD': 5, 'ISRG': 3, 'INTC': 5} # world fuel services, advanced micro devices, intuitive surgical, intel


# def read_data_link():
#     data_link = 'https://www.dropbox.com/s/6kh2u0qotscww5n/component.csv?raw=1'
#     response = r.get(data_link)
#     content = io.StringIO(response.text)
#     data_df = pd.read_csv(content)
#     return(data_df)

# data=read_data_link()


data_link = 'https://www.dropbox.com/s/6kh2u0qotscww5n/component.csv?raw=1'

response = r.get(data_link)
content = io.StringIO(response.text)
data = pd.read_csv(content)

stocks = data['Symbol']
sector = data['Sector']

tickers = stocks
number_of_shares = tickers_dict.values()

# %%
import time
##### Scrape the Date, Time and News Headlines Data
finwiz_url = 'https://finviz.com/quote.ashx?t='
news_tables = {}

for ticker in tickers:
    # print(ticker)
    url = finwiz_url + ticker
    req = Request(url=url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) Gecko/20100101 Firefox/20.0'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

    time.sleep(0.5)
    
news_table
# Out:
# <table border="0" cellpadding="1" cellspacing="0" class="fullview-news-outer" id="news-table" width="100%">
# <tr class="cursor-pointer" onclick="trackAndOpenNews(event, 'Motley Fool', 'https://finance.yahoo.com/m/d43d6e0d-bc30-3edf-a242-54ff19ab00cd/exxonmobil-is-spending-%244.9.html');">
# <td align="right" width="130">
#             Jul-14-23 07:15AM
#         </td>
# <td align="left">
# <div class="news-link-container">
# <div class="news-link-left">
# <a class="tab-link-news" href="https://finance.yahoo.com/m/d43d6e0d-bc30-3edf-a242-54ff19ab00cd/exxonmobil-is-spending-%244.9.html" rel="nofollow" target="_blank">ExxonMobil Is Spending $4.9 Billion to Accelerate Its Lower-Carbon Energy Ambitions</a>
# </div>
# <div class="news-link-right">
# <span>(Motley Fool)</span></div></div></td></tr>
# <tr class="cursor-pointer" onclick="trackAndOpenNews(event, 'The Wall Street Journal', 'https://finance.yahoo.com/m/232999ff-2ca0-3cc5-b59d-fac8c75cc10b/exxon-buys-pipeline-operator%2C.html');">
# <td align="right" width="130">
#             Jul-13-23 09:18PM
#         </td>
# <td align="left">
# <div class="news-link-container">
# <div class="news-link-left">
# <a class="tab-link-news" href="https://finance.yahoo.com/m
00AM
#         </td>
# <td align="left">
# <div class="news-link-container">
# <div class="news-link-left">
# <a class="tab-link-news" href="https://finance.yahoo.com/news/investors-exxon-mobil-nyse-xom-110054736.html" rel="nofollow" target="_blank">Investors in Exxon Mobil (NYSE:XOM) have seen strong returns of 164% over the past three years</a>
# </div>
# <div class="news-link-right">
# <span>(Simply Wall St.)</span></div></div></td></tr>
# <tr class="cursor-pointer" onclick="trackAndOpenNews(event, 'Reuters', 'https://finance.yahoo.com/news/insight-inside-race-remake-lithium-110000427.html');">
# <td align="right" width="130">
#             07:00AM
#         </td>
# <td align="left">
# <div class="news-link-container">
# <div class="news-link-left">
# <a class="tab-link-news" href="https://finance.yahoo.com/news/insight-inside-race-remake-lithium-110000427.html" rel="nofollow" target="_blank">INSIGHT-Inside the race to remake lithium extraction for EV batteries</a>
# </div>
# <div class="news-link-right">
# <span>(Reuters)</span></div></div></td></tr>
# <tr class="cursor-pointer" onclick="trackAndOpenNews(event, 'Zacks', 'https://finance.yahoo.com/news/tales-stock-compounding-does-always-230900321.html');">
# <td align="right" width="130">
#             Jun-15-23 07:09PM
#         </td>
# <td align="left">
# <div class="news-link-container">
# <div class="news-link-left">
# <a class="tab-link-news" href="https://finance.yahoo.com/news/tales-stock-compounding-does-always-230900321.html" rel="nofollow" target="_blank">Tales of Stock Compounding: Does It Always Work?</a>
# </div>
# <div class="news-link-right">
# <span>(Zacks)</span></div></div></td></tr>
# </table>

# %%
##### Parse the Date, Time and News Headlines into a Python List
parsed_news = []
# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # Check if the 'a' tag exists within the 'tr' tag
        if x.a is not None:
            # Read the text from the 'a' tag
            text = x.a.get_text()
            date_scrape = x.td.text.split()
            # if the length of 'date_scrape' is 1, load 'time' as the only element
            if len(date_scrape) == 1:
                time = date_scrape[0]
                
            # else load 'date' as the 1st element and 'time' as the second    
            else:
                date = date_scrape[0]
                time = date_scrape[1]
            # Extract the ticker from the file name, get the string up to the 1st '_'  
            ticker = file_name.split('_')[0]
            
            # Append ticker, date, time and headline as a list to the 'parsed_news' list
            parsed_news.append([ticker, date, time, text])

        else:
            # Handle cases where the 'a' tag is not found as desired
            text = "Not found"  # Or any other value or action depending on your needs
       
parsed_news
# Out:
# [['AAPL',
#   'Jul-14-23',
#   '08:00AM',
#   'Warren Buffetts Favorite Dividend Stocks  Should You Invest?'],
#  ['AAPL',
#   'Jul-14-23',
#   '07:30AM',
#   '2 No-Brainer Growth Stocks Up 46% and 63% to Buy Before the Next Bull Market'],
#  ['AAPL',
#   'Jul-14-23',
#   '06:20AM',
#   'Amazon has become one the most boring stories in tech: Morning Brief'],
#  ['AAPL',
#   'Jul-14-23',
#   '06:05AM',
#   '2 Under-the-Radar Gaming Stocks You Can Buy and Hold for the Next Decade'],
#  ['AAPL',
#   'Jul-14-23',
#   '05:50AM',
#   '3 Best Buffett Stocks to Buy for the Long Haul'],
#  ['AAPL',
#   'Jul-14-23',
#   '05:35AM',
#   'Got $3,000? 2 Tech Stocks to Buy and Hold for the Long Term'],
#  ['AAPL',
#   'Jul-14-23',
#   '05:26AM',
#   'Is This Top Tech Stock About to Become the Next $3 Trillion Company?'],
#  ['AAPL', 'Jul-13-23', '07:14PM', 'The 2023 Unhedged stock draft'],
#  ['AAPL',
#   'Jul-13-23',
#   '05:55PM',
#   '3 Stocks to Buy for Artificial Intelligence (AI) Exposure'],
#  ['AAPL',
#   'Jul-13-23',
#   '04:29PM',
#   "Which Companies Could Buy a Stake in Disney's ESPN?"],
#  ['AAPL',
#   'Jul-13-23',
#   '04:15PM',
#   "Hollywood actors strike could be a 'near-term benefit' for streamers: Analyst"],
#  ['AAPL',
#   'Jul-13-23',
#   '01:34PM',
#   'Apple Defies Decline As iPhone Market Share Surges Amid Smartphone Slump'],
#  ['AAPL',
#   'Jul-13-23',
#   '11:08AM',
#   "Apple's (AAPL) Streaming Service Receives 54 Emmy Nominations"],
#  ['AAPL',
#   'Jul-13-23',
#   '10:31AM',
#   'Apples British sales bounce back to record £1.5bn after Covid slump'],
#  ['AAPL', 'Jul-13-23', '09:45AM', '2 Stocks to Invest in Virtual Reality'],
#  ['AAPL',
#   'Jul-13-23',
#   '09:41AM',
#   'If You Invested $1,000 in Meta Platforms in 2022, This Is How Much You Would Have Today'],
#  ['AAPL',
#   'Jul-13-23',
#   '08:13AM',
#   'Boise Cascade and Cross Country Healthcare have been highlighted as Zacks Bull and Bear of the Day'],
#  ['AAPL',
#   'Jul-13-23',
#   '06:08AM',
#   "Apple Just Hit a $3 Trillion Market Cap. Here's Why It Could Get Even Bigger."],
#  ['AAPL',
#   'Jul-13-23',
#   '06:00AM',
#   'Now could be the worst time to buy Apple stock. Yes, reallyjust look at Robert Shillers famous CAPE metric'],
#  ['AAPL',
#   'Jul-12-23',
#   '10:01PM',
#   "Nasdaq 100 Plans Special Rebalance To Curb Dominance Of 'Magnificent Seven'"],
#  ['AAPL',
#   'Jul-12-23',
#   '04:33PM',
#   'Apple lands record 54 Emmy Award nominations, and makes history as "Ted Lasso" becomes the most Emmy-nominated comedy for the third consecutive year, and "STILL: A Michael J. Fox Movie" becomes most-nominated documentary'],
#  ['AAPL', 'Jul-12-23', '03:58PM', '25 Most Owned Stocks by Hedge Funds'],
#  ['AAPL',
#   'Jul-12-23',
#   '10:15AM',
#   '2 Unstoppable Stocks That Could Join Apple, Microsoft, Nvidia, Amazon, and Alphabet in the $1 Trillion Club'],
#  ['AAPL',
#   'Jul-12-23',
#   '10:14AM',
#   "At a $3 Trillion Market Cap, Has Apple's Stock Gotten Too Expensive?"],
#  ['AAPL',
#   'Jul-12-23',
#   '09:41AM',
#   'Q2 PC Shipment Data Shows Signs of Stabilization in PC Market'],
#  ['AAPL', 'Jul-12-23', '08:30AM', 'Better Buy: AMD vs. Apple'],
#  ['AAPL', 'Jul-12-23', '07:00AM', 'Is Apple Really Building a Car?'],
#  ['AAPL',
#   'Jul-12-23',
#   '06:00AM',
#   "RPT-EXPLAINER-What is Nasdaq's special rebalancing and its impact?"],
#  ['AAPL',
#   'Jul-12-23',
#   '05:40AM',
#   '1 Dark-Horse Growth Stock That Could Join Apple, Microsoft, and Alphabet in the $1 Trillion Club by 2033'],
#  ['AAPL',
#   'Jul-12-23',
#   '01:00AM',
#   'Inside the secret cyberwar against Putins regime'],
#  ['AAPL',
#   'Jul-12-23',
#   '01:00AM',
#   'Inside the murky world accelerating Russias economic meltdown'],
#  ['AAPL',
#   'Jul-11-23',
#   '05:45PM',
#   'Apple (AAPL) Stock Sinks As Market Gains: What You Should Know'],
#  ['AAPL', 'Jul-11-23', '04:47PM', 'Dow Jones Today: Index Jumps 300 Points'],
#  ['AAPL',
#   'Jul-11-23',
#   '03:53PM',
#   'GM is ditching Apple CarPlay & dealers are reportedly concerned'],
#  ['AAPL',
#   'Jul-11-23',
#   '02:05PM',
#   "Tata Group Inches Closer To Becoming India's First iPhone Maker"],
#  ['AAPL', 'Jul-11-23', '01:33PM', '13 Best Forever Stocks to Buy Now'],
#  ['AAPL',
#   'Jul-11-23',
#   '01:18PM',
#   "EXPLAINER-What is Nasdaq's special rebalancing and its impact?"],
#  ['AAPL',
#   'Jul-11-23',
#   '01:16PM',
#   'GM ditching Apple CarPlay has dealers concerned'],
#  ['AAPL',
#   'Jul-11-23',
#   '12:39PM',
#   "Nasdaq 100 to rebalance due to 'magnificent seven' dominance"],
#  ['AAPL',
#   'Jul-11-23',
#   '11:55AM',
#   'Apple/China: tech trade war has not halted a deepening relationship'],
#  ['AAPL',
#   'Jul-11-23',
#   '11:27AM',
#   "Amazon Analysts Estimate Deeper Discounts On Prime Day, Meta Platforms Threads App Can Generate Annual Sales Of $8B In 2 years, Uber's CFO Departs: Today's Top Stories"],
#  ['AAPL',
#   'Jul-11-23',
#   '10:56AM',
#   'HP, Apple PC Shipments Are Bright Spots in a Q2 Slump'],
#  ['AAPL',
#   'Jul-11-23',
#   '09:55AM',
#   "Apple's WeChat Store Aimed At Boosting China Sales"],
#  ['AAPL',
#   'Jul-11-23',
#   '09:21AM',
#   'Apple (AAPL) Boosts Apple News Content With Popular Podcast'],
#  ['AAPL',
#   'Jul-11-23',
#   '09:15AM',
#   'Global PC shipments decline eases in Q2, Apple outperforms on MacBook Air demand - Canalys'],
#  ['AAPL',
#   'Jul-11-23',
#   '08:53AM',
#   '10 Generative AI Stocks To Watch Amidst Copyright Concerns'],
#  ['AAPL',
#   'Jul-11-23',
#   '07:32AM',
#   'Apple Stock Gets a Price Target Boost. Even a Spending Slowdown Cant Stop the Gains.'],
#  ['AAPL', 'Jul-11-23', '05:29AM', 'Gen Zs 25 Favorite Brands in 2023'],
#  ['AAPL',
#   'Jul-11-23',
#   '04:12AM',
#   'Amazon, WD-40, JPMorgan and Zillow rise premarket'],
#  ['AAPL',
#   'Jul-11-23',
#   '02:48AM',
#   "Apple launches store on Tencent's WeChat messaging app"],
#  ['AAPL',
#   'Jul-11-23',
#   '01:46AM',
#   "UPDATE 1-Apple opens store on China's WeChat platform"],
#  ['AAPL',
#   'Jul-11-23',
#   '01:45AM',
#   "Fed officials discuss rates, Amazon Prime Day arrives - what's moving markets"],
#  ['AAPL',
#   'Jul-11-23',
#   '01:43AM',
#   'Tata Group Closes In on Deal to Become First Indian IPhone Maker'],
#  ['AAPL', 'Jul-11-23', '01:30AM', 'The magnificent seven, revisited'],
#  ['AAPL',
#   'Jul-11-23',
#   '12:15AM',
#   "Apple opens store on China's WeChat platform"],
#  ['AAPL',
#   'Jul-11-23',
#   '12:04AM',
#   'Apple Store goes live on WeChat mini programme'],
#  ['AAPL',
#   'Jul-10-23',
#   '06:12PM',
#   'Market heavyweights dip ahead of Nasdaq 100 rebalance'],
#  ['AAPL',
#   'Jul-10-23',
#   '05:49PM',
#   '25 States with the Lowest Poverty Rates in America'],
#  ['AAPL',
#   'Jul-10-23',
#   '05:46PM',
#   'Apple May Not Like It, but Zapple Pay Finds Workaround for Bitcoin Tipping on Damus'],
#  ['AAPL',
#   'Jul-10-23',
#   '05:22PM',
#   'Big Techs Dominance in Stock Market Hits Breakpoint for Nasdaq 100'],
#  ['AAPL',
#   'Jul-10-23',
#   '04:21PM',
#   'Dow Jones Today: Index Gains Despite Tech Drop'],
#  ['AAPL',
#   'Jul-10-23',
#   '04:15PM',
#   'Apple iPhone 15 Production Behind Schedule, Could Mean Tight Launch Supply'],
#  ['AAPL',
#   'Jul-10-23',
#   '03:13PM',
#   'Why Apple and the Rest of Big Tech Are Getting Hit by the Nasdaq 100 Rebalance'],
#  ['AAPL', 'Jul-10-23', '01:45PM', 'Doug Kass: Just Who Is Left to Buy Apple?'],
#  ['AAPL',
#   'Jul-10-23',
#   '12:02PM',
#   "Foxconn Withdraws from $19.5B Semiconductor Joint Venture with Vedanta, Hindering India's Chipmaking Plans"],
#  ['AAPL',
#   'Jul-10-23',
#   '09:14AM',
#   "Here's My Top Stock to Buy Now--And It's Not Even Close"],
#  ['AAPL',
#   'Jul-10-23',
#   '08:36AM',
#   'Why Apple Surged 49.3% During the First Half of 2023'],
#  ['AAPL',
#   'Jul-10-23',
#   '05:21AM',
#   "1 FAANG Stock That's a Surefire Buy in July and 1 to Avoid Like the Plague"],
#  ['AAPL',
#   'Jul-09-23',
#   '11:00AM',
#   'Taiwan Semiconductor (TSMC) Stock: Bear vs. Bull'],
#  ['AAPL',
#   'Jul-09-23',
#   '08:45AM',
#   'What Does the S&P 500 Index Measure and How Is It Calculated?'],
#  ['AAPL', 'Jul-09-23', '06:32AM', 'Can Shiba Inu Reach $1?'],
#  ['AAPL', 'Jul-09-23', '06:20AM', '20 Countries With The Best Architecture'],
#  ['AAPL',
#   'Jul-08-23',
#   '12:00PM',
#   '2 Roaring Stocks to Hold for the Next 20 Years'],
#  ['AAPL',
#   'Jul-08-23',
#   '11:33AM',
#   'What Delta and General Mills Reveal About the Economy'],
#  ['AAPL',
#   'Jul-08-23',
#   '10:00AM',
#   'The threat of a UPS strike is testing the strength of the labor market'],
#  ['AAPL',
#   'Jul-08-23',
#   '09:00AM',
#   'Your Smartphone Can Have Two Lines. Heres Why Youd Want That.'],
#  ['AAPL',
#   'Jul-08-23',
#   '08:00AM',
#   '2 Top Stocks to Buy for the Next Bull Market'],
#  ['AAPL',
#   'Jul-08-23',
#   '06:50AM',
#   'If You Invested $2,000 in Berkshire Hathaway in 2017, This Is How Much You Would Have Today'],
#  ['AAPL', 'Jul-07-23', '06:28PM', 'Weekly Roundup'],
#  ['AAPL',
#   'Jul-07-23',
#   '04:20PM',
#   '25 US Companies With The Highest Profit Margins'],
#  ['AAPL',
#   'Jul-07-23',
#   '04:18PM',
#   'Apple requiring appointment to buy Vision Pro headset; Report'],
#  ['AAPL',
#   'Jul-07-23',
#   '12:50PM',
#   'The 5 Worst Things to Buy on Amazon Prime Day'],
#  ['AAPL',
#   'Jul-07-23',
#   '10:32AM',
#   'Samsung Braces for Weakest Earnings in 14 Years. Chips Are the Problem.'],
#  ['AAPL',
#   'Jul-07-23',
#   '10:00AM',
#   'Investors in Apple (NASDAQ:AAPL) have seen incredible returns of 320% over the past five years'],
#  ['AAPL',
#   'Jul-07-23',
#   '09:00AM',
#   'Here is What to Know Beyond Why Apple Inc. (AAPL) is a Trending Stock'],
#  ['AAPL',
#   'Jul-07-23',
#   '07:35AM',
#   'Apple Rival Samsung Braces for Weakest Earnings in 14 Years. Chips Are the Problem.'],
#  ['AAPL', 'Jul-07-23', '06:39AM', 'Is Apple (AAPL)s Digi Wallet Safe?'],
#  ['AAPL',
#   'Jul-07-23',
#   '05:59AM',
#   'Here are Manole Capital Managements Thoughts about Alphabet (GOOG)s Digi Wallet'],
#  ['AAPL',
#   'Jul-07-23',
#   '05:06AM',
#   "Nearly Half of Warren Buffett's Dividend Income Comes From Just 3 Stocks"],
#  ['AAPL',
#   'Jul-07-23',
#   '05:00AM',
#   'Apple Plans a Slow, Appointment-Only Rollout of Its $3,500 Vision Pro'],
#  ['AAPL',
#   'Jul-07-23',
#   '12:00AM',
#   'Apples headset headache: the tiny and costly displays inside the Vision Pro'],
#  ['AAPL',
#   'Jul-06-23',
#   '11:44PM',
#   '20 Countries with the Best Economy in the World'],
#  ['AAPL',
#   'Jul-06-23',
#   '04:25PM',
#   'AI Seen Fueling Microsoft to $3 Trillion Value in Morgan Stanley Model'],
#  ['AAPL', 'Jul-06-23', '11:24AM', '12 Best Major Stocks to Buy Now'],
#  ['AAPL',
#   'Jul-06-23',
#   '11:08AM',
#   'Apple Stock Dips Below $3 Trillion Market Cap'],
#  ['AAPL',
#   'Jul-06-23',
#   '09:40AM',
#   'Billionaire Ken Fisher Says "High-Quality Growth" Is the Key to Investing in Artificial Intelligence. These Two AI Stocks Are His Biggest Holdings by Far.'],
#  ['AAPL',
#   'Jul-06-23',
#   '05:50AM',
#   "Here's How Much Higher Wall Street Thinks Apple Stock Will Go"],
#  ['AAPL',
#   'Jul-06-23',
#   '05:47AM',
#   'Analyst Dan Ives Says AI Could Push Microsoft Into the $3 Trillion Club With Apple by Early 2024'],
#  ['AAPL',
#   'Jul-06-23',
#   '05:30AM',
#   'How AI Is Already Reshaping White-Collar Work'],
#  ['AAPL',
#   'Jul-06-23',
#   '04:03AM',
#   "China's export curbs and Asian chipmakers' green dilemma"],
#  ['ABBV',
#   'Jul-13-23',
#   '05:45PM',
#   'AbbVie (ABBV) Stock Sinks As Market Gains: What You Should Know'],
#  ['ABBV',
#   'Jul-13-23',
#   '11:50AM',
#   'Big Pharma Ramps Up Fight Against Medicare Price Negotiations'],
#  ['ABBV',
#   'Jul-13-23',
#   '10:01AM',
#   'AbbVie (NYSE:ABBV) shareholders have earned a 14% CAGR over the last five years'],
#  ['ABBV',
#   'Jul-12-23',
#   '10:52AM',
#   "Incyte's (INCY) Opzelura Meets Goal in Phase III Pediatric Study"],
#  ['ABBV',
#   'Jul-12-23',
#   '07:57AM',
#   'Novo Nordisk (NVO) Falls on EMA Safety Review of Obesity Drugs'],
#  ['ABBV',
#   'Jul-11-23',
#   '12:24PM',
#   'Roche (RHHBY) Blood Cancer Drug Columvi Wins EC Approval'],
#  ['ABBV',
#   'Jul-10-23',
#   '11:31AM',
#   'Bausch Health (BHC) Secures $600M Financing Facility, Stock Up'],
#  ['ABBV',
#   'Jul-10-23',
#   '11:14AM',
#   'Novartis (NVS) Entresto Patent Faces Setback, Stock Down'],
#  ['ABBV',
#   'Jul-10-23',
#   '10:38AM',
#   'UPDATE 2-Cigna to add three Humira biosimilars to drug reimbursement list'],
#  ['ABBV',
#   'Jul-10-23',
#   '10:00AM',
#   'Cigna to add three Humira biosimilars to drug reimbursement list'],
#  ['ABBV',
#   'Jul-10-23',
#   '08:36AM',
#   "Zacks.com featured highlights include Dillard's, Suzano, Atkore, Nexstar Media Group and AbbVie"],
#  ['ABBV',
#   'Jul-09-23',
#   '07:00AM',
#   'Insiders At AbbVie Sold US$8.4m In Stock, Alluding To Potential Weakness'],
#  ['ABBV', 'Jul-08-23', '06:14AM', '3 No-Brainer Stocks You Can Buy Right Now'],
#  ['ABBV',
#   'Jul-07-23',
#   '10:51AM',
#   "Mark Cuban's online pharmacy to launch Humira biosimilar"],
#  ['ABBV',
#   'Jul-07-23',
#   '09:45AM',
#   '2 Struggling Dividend Growth Stocks That Could Make You Richer'],
#  ['ABBV',
#   'Jul-07-23',
#   '08:09AM',
#   'Buy 5 High ROE Stocks as Market Rally Skids on ADP Jobs Data'],
#  ['ABBV',
#   'Jul-07-23',
#   '07:15AM',
#   'Why Dividend Stocks Should Be a Key Part of Your Retirement Plan'],
#  ['ABBV',
#   'Jul-06-23',
#   '05:45PM',
#   'AbbVie (ABBV) Stock Moves -0.27%: What You Should Know'],
#  ['ABBV',
#   'Jul-06-23',
#   '05:02PM',
#   'UPDATE 1-AbbVie trims full-year profit forecast on higher R&D expenses'],
#  ['ABBV',
#   'Jul-06-23',
#   '04:33PM',
#   'AbbVie trims full-year profit forecast on higher R&D expenses'],
#  ['ABBV',
#   'Jul-06-23',
#   '04:31PM',
#   'AbbVie trims full-year profit forecast due to higher R&D expenses'],
#  ['ABBV', 'Jul-06-23', '01:32PM', "Is AbbVie's Dividend Yield Safe?"],
#  ['ABBV',
#   'Jul-06-23',
#   '10:29AM',
#   'Sarepta (SRPT) Sells Priority Review Voucher for $102M'],
#  ['ABBV',
#   'Jul-06-23',
#   '09:45AM',
#   'Got $5,000? These Are 3 of the Best Stocks to Buy in July'],
#  ['ABBV',
#   'Jul-06-23',
#   '09:00AM',
#   'AbbVie Inc. (ABBV) Is a Trending Stock: Facts to Know Before Betting on It'],
#  ['ABBV',
#   'Jul-06-23',
#   '08:00AM',
#   'AbbVie to Host Second-Quarter 2023 Earnings Conference Call'],
#  ['ABBV',
#   'Jul-05-23',
#   '02:50PM',
#   "Mark Cuban's online pharmacy set to launch Humira biosimilar"],
#  ['ABBV',
#   'Jul-05-23',
#   '07:30AM',
#   "Celltrion launches biosimilar of AbbVie's blockbuster drug Humira in US"],
#  ['ABBV',
#   'Jul-04-23',
#   '10:41AM',
#   'AstraZeneca (AZN) Down 9% on Mixed Lung Cancer Study Results'],
#  ['ABBV',
#   'Jul-04-23',
#   '08:14AM',
#   '3 Spectacular Dividend Stocks to Buy in July'],
#  ['ABBV',
#   'Jul-04-23',
#   '07:00AM',
#   'These 4 Measures Indicate That AbbVie (NYSE:ABBV) Is Using Debt Reasonably Well'],
#  ['ABBV',
#   'Jul-03-23',
#   '01:51PM',
#   "India's Biocon Biologics launches biosimilar for AbbVie's Humira in US"],
#  ['ABBV',
#   'Jul-03-23',
#   '12:18PM',
#   'Novartis (NVS) to Divest Xiidra, SAF312 to Streamline Focus'],
#  ['ABBV',
#   'Jul-03-23',
#   '10:55AM',
#   "Fresenius launches biosimilar version of AbbVie's Humira at 5% discount"],
#  ['ABBV',
#   'Jul-03-23',
#   '09:15AM',
#   "Merck and AbbVie Are Facing Big Patent Cliffs, But Here's Why Both Are Still Buys"],
#  ['ABBV',
#   'Jul-03-23',
#   '08:52AM',
#   "UPDATE 1-Coherus BioSciences launches biosimilar version of AbbVie's blockbuster Humira"],
#  ['ABBV',
#   'Jul-03-23',
#   '05:52AM',
#   '3 Magnificent Dividend Stocks to Buy Hand Over Fist in July'],
#  ['ABBV', 'Jul-02-23', '03:09PM', '10 Best Dividend Penny Stocks to Buy Now'],
#  ['ABBV',
#   'Jul-02-23',
#   '09:30AM',
#   'Could This New Drug Be a Blockbuster for These 2 Pharma Collaborators?'],
#  ['ABBV',
#   'Jul-01-23',
#   '08:28AM',
#   'RPT-UPDATE 1-Organon, Samsung Bioepis launch copycat for arthritis drug Humira at 85% discount'],
#  ['ABBV',
#   'Jul-01-23',
#   '08:00AM',
#   'REFILE-UPDATE 1-Organon, Samsung Bioepis launch copycat for arthritis drug Humira at 85% discount'],
#  ['ABBV',
#   'Jul-01-23',
#   '06:30AM',
#   'Organon, Samsung Bioepis launch copycat for athritis drug Humira at 85% discount'],
#  ['ABBV',
#   'Jul-01-23',
#   '12:20AM',
#   "Sandoz launches rival version of AbbVie's arthritis drug Humira"],
#  ['ABBV',
#   'Jun-30-23',
#   '02:13PM',
#   'Medicare releases updated guidance ahead of drug price negotiations'],
#  ['ABBV', 'Jun-30-23', '12:59PM', 'Why Shares of Alvotech Are Jumping Friday'],
#  ['ABBV',
#   'Jun-30-23',
#   '10:57AM',
#   'BioMarin (BMRN) Gets FDA Nod for Hemophilia A Gene Therapy'],
#  ['ABBV',
#   'Jun-30-23',
#   '09:07AM',
#   'Sigilon (SGTX) Skyrockets 441% on Buyout Offer From Eli Lilly'],
#  ['ABBV',
#   'Jun-30-23',
#   '07:01AM',
#   "Is AbbVie Inc.'s (NYSE:ABBV) ROE Of 57% Impressive?"],
#  ['ABBV', 'Jun-29-23', '05:15PM', '3 Dividend Kings Yielding Royal Sums'],
#  ['ABBV',
#   'Jun-29-23',
#   '03:01PM',
#   'Cheaper competition for Humira is hitting the market, but savings will depend on your insurance'],
#  ['ABBV',
#   'Jun-29-23',
#   '02:17PM',
#   "Moody's: Pharma outlook stable for next 12-18 months, but with caveats"],
#  ['ABBV',
#   'Jun-29-23',
#   '10:00AM',
#   '5 High-Yielding Dividend Stocks That Are Bargain Buys'],
#  ['ABBV',
#   'Jun-28-23',
#   '09:25AM',
#   '12 Best Long-Term Dividend Stocks To Buy Now'],
#  ['ABBV', 'Jun-28-23', '08:30AM', 'What Will AbbVie Buy Next?'],
#  ['ABBV',
#   'Jun-28-23',
#   '06:30AM',
#   'Kineta Expands Board of Directors with Biotech Industry Leaders Kim Drapkin and Scott Dylla'],
#  ['ABBV',
#   'Jun-28-23',
#   '05:26AM',
#   'The Zacks Analyst Blog Highlights Novo Nordisk, Home Depot, Disney, AbbVie and Automatic Data Processing'],
#  ['ABBV',
#   'Jun-27-23',
#   '06:50PM',
#   'AbbVie and Genmab Announce Positive Topline Results from Phase 1/2 EPCORE NHL-1 Trial Evaluating Epcoritamab (DuoBody®-CD3xCD20) in Patients with Relapsed/Refractory Follicular Lymphoma (FL)'],
#  ['ABBV',
#   'Jun-27-23',
#   '12:29PM',
#   'Top Stock Reports for Novo Nordisk, Home Depot & Walt Disney'],
#  ['ABBV',
#   'Jun-26-23',
#   '05:45PM',
#   'AbbVie (ABBV) Dips More Than Broader Markets: What You Should Know'],
#  ['ABBV',
#   'Jun-26-23',
#   '11:23AM',
#   'AbbVie (ABBV) Gets CHMP Positive Opinion for Atogepant Approval'],
#  ['ABBV',
#   'Jun-26-23',
#   '08:00AM',
#   'AbbVie Employees Volunteer During 8th Annual "Week of Possibilities" to Support Communities Globally'],
#  ['ABBV',
#   'Jun-26-23',
#   '06:20AM',
#   'Should SPDR Portfolio S&P 500 High Dividend ETF (SPYD) Be on Your Investing Radar?'],
#  ['ABBV',
#   'Jun-25-23',
#   '05:55AM',
#   '1 Phenomenal High-Yield Dividend Stock You Can Buy and Hold Forever'],
#  ['ABBV', 'Jun-24-23', '03:19PM', '11 Best Medical\xa0 Stocks Under $10'],
#  ['ABBV',
#   'Jun-24-23',
#   '02:26PM',
#   '10 Personalized Medicine Stocks Billionaires Are Loading Up On'],
#  ['ABBV', 'Jun-24-23', '12:38PM', 'Top 30 S&P 500 Stocks by Index Weight'],
#  ['ABBV',
#   'Jun-24-23',
#   '07:20AM',
#   '4 Stocks That Can Turn $100,000 Into $500,000 by the Time You Retire'],
#  ['ABBV',
#   'Jun-23-23',
#   '07:30PM',
#   '10 Companies Likely to be Dividend Aristocrats in the Future'],
#  ['ABBV',
#   'Jun-23-23',
#   '12:16PM',
#   "CORRECTED-UnitedHealth unit to add Boehringer's Humira biosimilar to reimbursement list (June 23)"],
#  ['ABBV',
#   'Jun-23-23',
#   '08:04AM',
#   'AbbVie Secures Positive CHMP Opinion for Atogepant for the Preventive Treatment of Adults with Migraine'],
#  ['ABBV', 'Jun-22-23', '01:13PM', 'AbbVie Declares Quarterly Dividend'],
#  ['ABBV',
#   'Jun-22-23',
#   '09:00AM',
#   'Investors Heavily Search AbbVie Inc. (ABBV): Here is What You Need to Know'],
#  ['ABBV',
#   'Jun-22-23',
#   '08:00AM',
#   '2 No-Brainer Healthcare Stocks to Buy Right Now'],
#  ['ABBV',
#   'Jun-21-23',
#   '05:00AM',
#   'The Zacks Analyst Blog Highlights PepsiCo, AbbVie, Honeywell, Salesforce and Goldman Sachs'],
#  ['ABBV',
#   'Jun-20-23',
#   '05:45PM',
#   'AbbVie (ABBV) Dips More Than Broader Markets: What You Should Know'],
#  ['ABBV',
#   'Jun-20-23',
#   '12:21PM',
#   'Top Analyst Reports for PepsiCo, AbbVie & Honeywell'],
#  ['ABBV',
#   'Jun-19-23',
#   '11:01AM',
#   "Lilly's (LLY) Migraine Drug Fails Vis-a-Vis Pfizer's Nurtec ODT"],
#  ['ABBV',
#   'Jun-16-23',
#   '08:30AM',
#   "This Biotech Is About to Eat AbbVie's Market Share, but Is It a Buy?"],
#  ['ABBV',
#   'Jun-16-23',
#   '07:45AM',
#   "AbbVie's (ABBV) Skyrizi Meets Ulcerative Colitis Study Goals"],
#  ['ABBV',
#   'Jun-16-23',
#   '07:18AM',
#   "CORRECTED-Roche's cancer therapy gets US FDA nod, heating up competition with AbbVie (June 16)"],
#  ['ABBV',
#   'Jun-15-23',
#   '01:39PM',
#   'AbbVie Touts Promising Results For Risankizumab For Ulcerative Colitis Maintenance'],
#  ['ABBV',
#   'Jun-15-23',
#   '01:24PM',
#   'AbbVie vs Coherus: Dispute Emerges over Upcoming Launch of Low-Cost Biosimilar, Yusimry'],
#  ['ABBV',
#   'Jun-15-23',
#   '01:20PM',
#   "AbbVie Says BeiGene's Flagship Blood Cancer Drug Infringes Imbruvica Patent"],
#  ['ABBV',
#   'Jun-15-23',
#   '10:49AM',
#   'UPDATE 1-Coherus resolves part of dispute with AbbVie over Humira biosimilar'],
#  ['ABBV',
#   'Jun-15-23',
#   '08:45AM',
#   'Risankizumab (SKYRIZI®) Met Primary and Key Secondary Endpoints in 52-Week Phase 3 Maintenance Study in Ulcerative Colitis Patients'],
#  ['ABBV',
#   'Jun-15-23',
#   '07:07AM',
#   'Abbvie, Coherus agree to resolve dispute over Humira biosimilar'],
#  ['ABBV',
#   'Jun-14-23',
#   '08:00AM',
#   'AbbVie Inc. (NYSE:ABBV) is favoured by institutional owners who hold 71% of the company'],
#  ['ABBV',
#   'Jun-13-23',
#   '01:49PM',
#   "Mustang (MBIO) Up 9% on Rare Blood Cancer Study's Upbeat Data"],
#  ['ABBV',
#   'Jun-13-23',
#   '09:18AM',
#   'Ironwood (IRWD), AbbVie Get FDA Nod for Linzess Label Expansion'],
#  ['ABBV',
#   'Jun-13-23',
#   '08:45AM',
#   'BOTOX® Cosmetic (onabotulinumtoxinA) Announces the Winners of the IFundWomen Grant Program'],
#  ['ABBV',
#   'Jun-13-23',
#   '06:52AM',
#   'Top 20 Most Profitable Pharmaceutical Companies In The World'],
#  ['ABBV',
#   'Jun-13-23',
#   '06:20AM',
#   'Is SPDR Portfolio S&P 500 High Dividend ETF (SPYD) a Strong ETF Right Now?'],
#  ['ABBV', 'Jun-13-23', '06:04AM', '15 Most Profitable Drugs In The World'],
#  ['ABBV',
#   'Jun-12-23',
#   '05:45PM',
#   'AbbVie (ABBV) Stock Sinks As Market Gains: What You Should Know'],
#  ['ABBV',
#   'Jun-10-23',
#   '08:05AM',
#   'Better Long-Term Buy: AbbVie or Novo Nordisk?'],
#  ['ABBV',
#   'Jun-09-23',
#   '09:00AM',
#   'Here is What to Know Beyond Why AbbVie Inc. (ABBV) is a Trending Stock'],
#  ['ABBV',
#   'Jun-09-23',
#   '03:00AM',
#   "AbbVie's VENCLYXTO®/VENCLEXTA® (venetoclax) Continues to Show Sustained Progression-Free Survival (PFS) in Chronic Lymphocytic Leukemia (CLL) Patients"],
#  ['ABBV',
#   'Jun-08-23',
#   '05:42PM',
#   '10 Reliable Dividend Stocks Billionaires Are Loading Up On'],
#  ['ABBV',
#   'Jun-08-23',
#   '12:15PM',
#   'Is AbbVie or Amgen the Better Bargain Buy Right Now?'],
#  ['ABBV',
#   'Jun-08-23',
#   '08:00AM',
#   'AbbVie Insiders Sell US$8.4m Of Stock, Possibly Signalling Caution \\'],
#  ['ABT',
#   'Jul-13-23',
#   '05:34PM',
#   "Abbott Labs, UnitedHealthcare, Oracle: Portfolio manager's stock buys and sells"],
#  ['ABT',
#   'Jul-13-23',
#   '10:01AM',
#   'Abbott (ABT) Expected to Beat Earnings Estimates: Can the Stock Move Higher?'],
#  ['ABT',
#   'Jul-13-23',
#   '05:43AM',
#   '5 Stocks to Buy Ahead of Q2 Earnings Next Week'],
#  ['ABT',
#   'Jul-12-23',
#   '12:07PM',
#   "What's in Store for Abbott Laboratories (ABT) in Q2 Earnings?"],
#  ['ABT',
#   'Jul-12-23',
#   '11:40AM',
#   'ABT vs. LMAT: Which Stock Should Value Investors Buy Now?'],
#  ['ABT',
#   'Jul-11-23',
#   '06:00PM',
#   'Abbott (ABT) Gains But Lags Market: What You Should Know'],
#  ['ABT',
#   'Jul-11-23',
#   '11:52AM',
#   "AngioDynamics (ANGO) to Report Q4 Earnings: What's in the Cards?"],
#  ['ABT',
#   'Jul-10-23',
#   '04:15PM',
#   'Shaping the Future of Abbott and Healthcare'],
#  ['ABT',
#   'Jul-06-23',
#   '08:46AM',
#   'Abbott (ABT) Gets FDA Approval for AVEIR DR Leadless Pacemaker'],
#  ['ABT',
#   'Jul-05-23',
#   '04:41PM',
#   'Moderna announces China investment as country opens doors to foreign pharma'],
#  ['ABT',
#   'Jul-05-23',
#   '12:10PM',
#   'Will Abbott (ABT) Beat Estimates Again in Its Next Earnings Report?'],
#  ['ABT',
#   'Jul-05-23',
#   '09:00AM',
#   "Abbott Receives FDA Approval for World's First Dual Chamber Leadless Pacemaker"],
#  ['ABT',
#   'Jul-03-23',
#   '05:50PM',
#   'Abbott (ABT) Stock Sinks As Market Gains: What You Should Know'],
#  ['ABT',
#   'Jul-03-23',
#   '09:00AM',
#   'Abbott Laboratories (NYSE:ABT) Might Have The Makings Of A Multi-Bagger'],
#  ['ABT',
#   'Jun-30-23',
#   '09:34AM',
#   'Abbott (ABT) Teams Up With the ADA to Evaluate CGM Systems'],
#  ['ABT',
#   'Jun-29-23',
#   '07:21PM',
#   'State Health Officials Aim to Boost Reporting of Infections Linked to Tainted Baby Formula'],
#  ['ABT',
#   'Jun-29-23',
#   '09:00AM',
#   'Abbott Hosts Conference Call for Second-Quarter Earnings'],
#  ['ABT',
#   'Jun-28-23',
#   '02:15PM',
#   'The American Diabetes Association and Abbott Collaborate on First-of-Its-Kind Therapeutic Nutrition Program for People With Diabetes'],
#  ['ABT',
#   'Jun-27-23',
#   '05:50PM',
#   'Abbott (ABT) Stock Sinks As Market Gains: What You Should Know'],
#  ['ABT',
#   'Jun-27-23',
#   '12:28PM',
#   'Abbott (ABT) EPD Sales Aid Growth Amid Currency Headwind'],
#  ['ABT',
#   'Jun-27-23',
#   '08:30AM',
#   "Here's How Much a $1000 Investment in Abbott Made 10 Years Ago Would Be Worth Today"],
#  ['ABT',
#   'Jun-26-23',
#   '12:30PM',
#   "Here's Why Investors Should Retain Abbott (ABT) Stock Now"],
#  ['ABT',
#   'Jun-24-23',
#   '02:26PM',
#   '10 Personalized Medicine Stocks Billionaires Are Loading Up On'],
#  ['ABT',
#   'Jun-23-23',
#   '12:28PM',
#   'Abbott (ABT) FreeStyle Libre 2 Gets Reimbursement in France'],
#  ['ABT', 'Jun-23-23', '10:27AM', 'Why Shares of Surmodics Jumped This Week'],
#  ['ABT',
#   'Jun-23-23',
#   '09:30AM',
#   'Abbott (ABT) Just Overtook the 50-Day Moving Average'],
#  ['ABT',
#   'Jun-22-23',
#   '09:00AM',
#   "Abbott's FreeStyle Libre® 2 Receives National Reimbursement in France for All People with Diabetes Who Use Insulin¹"],
#  ['ABT',
#   'Jun-21-23',
#   '05:50PM',
#   'Abbott (ABT) Stock Moves -0.42%: What You Should Know'],
#  ['ABT',
#   'Jun-21-23',
#   '06:10AM',
#   'Surmodics (SRDX) Rallies on FDA Approval for SurVeil DCB'],
#  ['ABT',
#   'Jun-20-23',
#   '11:54AM',
#   "After FDA Rejection, Surmodics' SurVeil Drug-Coated Balloon Scores FDA Approval"],
#  ['ABT',
#   'Jun-20-23',
#   '09:53AM',
#   '3 Passive Income Stocks to Hold for the Next 20 Years'],
#  ['ABT',
#   'Jun-15-23',
#   '07:00AM',
#   'Abbott Laboratories (NYSE:ABT) is favoured by institutional owners who hold 76% of the company'],
#  ['ABT',
#   'Jun-13-23',
#   '05:50PM',
#   'Abbott (ABT) Gains But Lags Market: What You Should Know'],
#  ['ABT', 'Jun-13-23', '01:11PM', 'Why Shares of Surmodics Soared on Tuesday'],
#  ['ABT',
#   'Jun-12-23',
#   '11:41AM',
#   'Abbott Labs Shuffles Finance Team with New CFO Appointment'],
#  ['ABT',
#   'Jun-12-23',
#   '11:25AM',
#   'Abbott (ABT) EPD Sales Gain Traction, Margin Pressure Lingers'],
#  ['ABT',
#   'Jun-10-23',
#   '09:00AM',
#   'Could The Market Be Wrong About Abbott Laboratories (NYSE:ABT) Given Its Attractive Financial Prospects?'],
#  ['ABT',
#   'Jun-09-23',
#   '10:55AM',
#   'Abbott Declares 398th Consecutive Quarterly Dividend'],
#  ['ABT', 'Jun-09-23', '09:34AM', '10 Best Recession-Proof Stocks to Buy Now'],
#  ['ABT',
#   'Jun-08-23',
#   '04:13PM',
#   '15 Healthcare Stocks Billionaires Are Loading Up On'],
#  ['ABT',
#   'Jun-08-23',
#   '11:49AM',
#   'Top Stock Reports for Procter & Gamble, Bank of America & Abbott Laboratories'],
#  ['ABT',
#   'Jun-07-23',
#   '05:45PM',
#   'Abbott (ABT) Dips More Than Broader Markets: What You Should Know'],
#  ['ABT',
#   'Jun-07-23',
#   '09:30AM',
#   'Abbott (ABT) Is Considered a Good Investment by Brokers: Is That True?'],
#  ['ABT',
#   'Jun-06-23',
#   '01:40PM',
#   "Abbott and Real Madrid's Goal: Beating Malnutrition"],
#  ['ABT',
#   'Jun-04-23',
#   '10:15AM',
#   "2 Dividend Kings Down 12% and 14% You'll Regret Not Buying on The Dip"],
#  ['ABT',
#   'Jun-01-23',
#   '05:45PM',
#   'Abbott (ABT) Gains But Lags Market: What You Should Know'],
#  ['ABT',
#   'Jun-01-23',
#   '04:15PM',
#   'Abbott, Real Madrid and the Real Madrid Foundation Band Together To Beat Malnutrition Globally Through New Campaign'],
#  ['ABT',
#   'May-31-23',
#   '05:50PM',
#   'Abbott (ABT) Gains As Market Dips: What You Should Know'],
#  ['ABT',
#   'May-31-23',
#   '11:37AM',
#   'Abbott accuses one of its former scientists of trade-secrets theft in US court'],
#  ['ABT',
#   'May-31-23',
#   '09:00AM',
#   "Abbott, Real Madrid and the Real Madrid Foundation Band Together to 'Beat Malnutrition' Globally Through New Campaign"],
#  ['ABT', 'May-30-23', '01:06PM', 'The Argus ESG Model Portfolio'],
#  ['ABT',
#   'May-30-23',
#   '09:39AM',
#   'Abbott (ABT) Reports Upbeat Cardiomems Sensor Study Result'],
#  ['ABT',
#   'May-25-23',
#   '05:45PM',
#   'Abbott (ABT) Stock Sinks As Market Gains: What You Should Know'],
#  ['ABT',
#   'May-24-23',
#   '12:53PM',
#   "More trouble? The FTC is investigating baby formula makers' state bidding practices."],
#  ['ABT',
#   'May-24-23',
#   '12:33PM',
#   'FTC Investigates Abbott For Alleged Collusion in Federal Baby Formula Contract Bids'],
#  ['ABT',
#   'May-24-23',
#   '12:07PM',
#   'Abbott (ABT) Unveils Late-Breaking Data on Leadless Pacemaker'],
#  ['ABT',
#   'May-24-23',
#   '11:37AM',
#   'Infant formula producers probed by FTC over bids for government contracts'],
#  ['ABT',
#   'May-24-23',
#   '10:39AM',
#   'Is There Collusion in the Baby-Formula Industry?: FTC Scrutinizes State Contracts Bidding Process'],
#  ['ABT',
#   'May-24-23',
#   '10:08AM',
#   'FTC investigating baby-formula makers on suspected collusion'],
#  ['ABT',
#   'May-24-23',
#   '09:38AM',
#   'Baby-Formula Makers Face FTC Investigation for Collusion'],
#  ['ABT',
#   'May-24-23',
#   '09:00AM',
#   'European Study Finds the Abbott CardioMEMS Sensor Results in Improved Quality of Life and 44% Reduction in Heart Failure Hospitalizations'],
#  ['ABT',
#   'May-24-23',
#   '03:24AM',
#   'FTC probing Abbott, other baby-formula makers for collusion'],
#  ['ABT',
#   'May-24-23',
#   '01:28AM',
#   'UPDATE 3-Abbott, baby formula makers face FTC probe for potential collusion'],
#  ['ABT',
#   'May-24-23',
#   '12:32AM',
#   'Abbott, other baby formula makers face FTC investigation for potential collusion'],
#  ['ABT',
#   'May-23-23',
#   '02:36PM',
#   "Abbott's Baby Formula Brouhaha: Judge Says No Harm, No Foul in Contamination Controversy"],
#  ['ABT',
#   'May-22-23',
#   '08:00PM',
#   'UPDATE 1-Judge tosses out some claims in Abbott baby formula litigation'],
#  ['ABT',
#   'May-22-23',
#   '06:01PM',
#   'Judge tosses out some claims in Abbott baby formula litigation'],
#  ['ABT',
#   'May-22-23',
#   '05:59PM',
#   'Judge tosses some claims in Abbott baby formula litigation'],
#  ['ABT',
#   'May-22-23',
#   '11:13AM',
#   'Abbott (ABT) Expands in Electrophysiology With New FDA Nod'],
#  ['ABT',
#   'May-20-23',
#   '09:18AM',
#   "Abbott Unveils Late-Breaking Data Showing the World's First Dual-Chamber Leadless Pacemaker Study Met All Three Primary Endpoints"],
#  ['ABT',
#   'May-19-23',
#   '03:23PM',
#   "Stereotaxis, Abbott Ink Pact To Combine Mapping & Robotic Tech: FDA Approves Abbott's Next-Gen Abalation Catheter"],
#  ['ABT',
#   'May-19-23',
#   '11:39AM',
#   "Abbott's (ABT) Assert-IQ Cardiac Monitor Receives FDA Approval"],
#  ['ABT',
#   'May-19-23',
#   '11:30AM',
#   'Abbott (ABT) Down 1.7% Since Last Earnings Report: Can It Rebound?'],
#  ['ABT',
#   'May-19-23',
#   '10:30AM',
#   'Coming Together on the Journey to End Parkinsons'],
#  ['ABT',
#   'May-19-23',
#   '09:00AM',
#   'Abbott Receives FDA Approval for TactiFlex Ablation Catheter for Treatment of Abnormal Heart Rhythm'],
#  ['ABT',
#   'May-18-23',
#   '09:00AM',
#   "Abbott Receives FDA Clearance for Assert-IQ Insertable Cardiac Monitor to Help Doctors Monitor People's Heart Rhythms Long-Term"],
#  ['ABT',
#   'May-17-23',
#   '12:55PM',
#   'Billionaire Paul Tudor Jones Pours Millions Into These 2 Stocks Amid Recession Fears'],
#  ['ABT',
#   'May-17-23',
#   '10:42AM',
#   'Billionaire Ray Dalios Top 12 Dividend Stock Picks'],
#  ['ABT',
#   'May-16-23',
#   '04:22PM',
#   "Back Off, Chronic Pain! FDA Nods for Abbott's Spinal Cord Stimulation Devices"],
#  ['ABT',
#   'May-16-23',
#   '11:44AM',
#   "Claims of PediaSure Boosting Children's Height Challenged in Lawsuit Against Abbott Laboratories"],
#  ['ABT',
#   'May-16-23',
#   '09:00AM',
#   'Abbott Receives FDA Approval for Its Spinal Cord Stimulation Systems to Treat Chronic Back Pain in People Who Have Limited Surgical Options'],
#  ['ABT',
#   'May-15-23',
#   '05:37PM',
#   'UPDATE 1-Abbott Labs is sued over PediaSure height claims'],
#  ['ABT',
#   'May-15-23',
#   '02:39PM',
#   'Abbott Labs is sued over PediaSure height claims'],
#  ['ABT',
#   'May-15-23',
#   '01:10PM',
#   "Abbott's (ABT) New Pact to Advance Clinical Trials Diversity"],
#  ['ABT',
#   'May-11-23',
#   '12:15PM',
#   'Abbott Announces New Partnerships and Programs To Advance Its Diversity in Clinical Trials Initiative'],
#  ['ABT',
#   'May-11-23',
#   '09:00AM',
#   'Abbott Announces New Partnerships and Programs to Advance its Diversity in Clinical Trials Initiative'],
#  ['ABT',
#   'May-09-23',
#   '09:37AM',
#   "Here's Why You Should Retain Abbott (ABT) Stock For Now"],
#  ['ABT',
#   'May-08-23',
#   '10:45AM',
#   'Abbott (ABT) EPD Business Grows Strong, Macro Issues Stay'],
#  ['ABT', 'May-08-23', '07:29AM', 'Analyst Report: Abbott Laboratories'],
#  ['ABT',
#   'May-08-23',
#   '07:14AM',
#   'Market Digest: ABT, EPD, MKTX, TMUS, VMC, CHTR, DD, SHOP, DKNG'],
#  ['ABT',
#   'May-05-23',
#   '12:28PM',
#   "Cigna (CI) Q1 Earnings Surpass Estimates, Ups '23 EPS View"],
#  ['ABT',
#   'May-05-23',
#   '07:49AM',
#   'Dividend Aristocrats Ranked: Top 15 According to Analysts'],
#  ['ABT',
#   'May-04-23',
#   '05:16AM',
#   'The Zacks Analyst Blog Highlights Berkshire Hathaway, Tesla, JPMorgan Chase, Abbott Laboratories and Comcast'],
#  ['ABT',
#   'May-03-23',
#   '05:40PM',
#   'Dividend Champions, Contenders and Challengers List: 15 Highest Yielding Stocks'],
#  ['ABT',
#   'May-02-23',
#   '02:57PM',
#   'Acadia Healthcare (ACHC) Q1 Earnings Beat on Higher Patient Volumes'],
#  ['ABT', 'May-02-23', '05:14AM', 'Is Dexcom a Good Stock to Buy Now?'],
#  ['ABT', 'May-01-23', '11:29AM', '3 Stocks to Buy on the Cusp of a Breakout'],
#  ['ABT',
#   'Apr-28-23',
#   '02:00PM',
#   'Got $1,000? 2 Top Dividend Stocks to Buy Now'],
#  ['ABT',
#   'Apr-27-23',
#   '04:10PM',
#   'Abbott Completes Acquisition of Cardiovascular Systems, Inc.'],
#  ['ABT',
#   'Apr-27-23',
#   '12:00PM',
#   'Climate Change: The Impact on Viral Outbreaks'],
#  ['ACN',
#   'Jul-13-23',
#   '08:00AM',
#   "Accenture plc's (NYSE:ACN) Intrinsic Value Is Potentially 18% Below Its Share Price"],
#  ['ACN',
#   'Jul-12-23',
#   '06:55PM',
#   'Googles AI Chatbot Is Trained by Humans Who Say Theyre Overworked, Underpaid and Frustrated'],
#  ['ACN',
#   'Jul-11-23',
#   '08:59AM',
#   'Accenture Federal Services Wins $94M U.S. Army Identity, Credential, and Access Management (ICAM) Contract'],
#  ['ACN',
#   'Jul-08-23',
#   '08:02AM',
#   'Accenture (NYSE:ACN) shareholders have earned a 14% CAGR over the last five years'],
#  ['ACN',
#   'Jul-07-23',
#   '12:16PM',
#   'Strategic Enhancements Aid Accenture (ACN) Amid Competition'],
#  ['ACN',
#   'Jul-07-23',
#   '09:49AM',
#   'The Zacks Analyst Blog Highlights Mastercard, Oracle, Adobe, Accenture and Qualcomm'],
#  ['ACN',
#   'Jul-06-23',
#   '11:57AM',
#   'Top Stock Reports for Mastercard, Oracle & Adobe'],
#  ['ACN', 'Jul-06-23', '11:14AM', '10 Best Technology Penny Stocks to Buy'],
#  ['ACN',
#   'Jul-06-23',
#   '08:59AM',
#   'Accenture Federal Services Wins $98M Defense Health Agency Award'],
#  ['ACN',
#   'Jul-05-23',
#   '04:33PM',
#   '17 Highest Paying Government Jobs Without a Degree'],
#  ['ACN',
#   'Jul-04-23',
#   '10:00AM',
#   "Accenture plc's (NYSE:ACN) Recent Stock Performance Looks Decent- Can Strong Fundamentals Be the Reason?"],
#  ['ACN',
#   'Jul-03-23',
#   '06:44PM',
#   '10 Stocks Jumping On The Generative AI Wagon'],
#  ['ACN',
#   'Jun-30-23',
#   '07:01AM',
#   'Accenture (NYSE:ACN) Will Want To Turn Around Its Return Trends'],
#  ['ACN',
#   'Jun-29-23',
#   '01:29PM',
#   'Accenture Appoints Rajendra Prasad as Chief Information and Asset Engineering Officer'],
#  ['ACN',
#   'Jun-29-23',
#   '12:11AM',
#   "Commerzbank sees 25% return potential in Accenture shares, rates 'Strong Buy'"],
#  ['ACN', 'Jun-27-23', '11:31AM', 'The Argus Dividend Growth Model Portfolio'],
#  ['ACN', 'Jun-26-23', '03:55PM', 'Actively Training for AI: Accenture CEO'],
#  ['ACN', 'Jun-25-23', '07:40AM', 'Is Accenture Stock a Buy Now?'],
#  ['ACN', 'Jun-23-23', '06:43PM', 'Why Accenture Stock Flopped on Friday'],
#  ['ACN',
#   'Jun-23-23',
#   '12:37PM',
#   'Accenture CEO Weighs in on that Disappointing Forecast'],
#  ['ACN', 'Jun-23-23', '07:35AM', 'Market Digest: ACN, DHI, HUM, NYT, UTI'],
#  ['ACN', 'Jun-23-23', '07:35AM', 'Analyst Report: Accenture PLC'],
#  ['ACN',
#   'Jun-23-23',
#   '02:00AM',
#   'Heres Why Polen Capital International Growth Strategy Trimmed Accenture plc (ACN) in Q1'],
#  ['ACN', 'Jun-22-23', '04:43PM', 'Analyst Report: Accenture plc'],
#  ['ACN',
#   'Jun-22-23',
#   '04:35PM',
#   'US STOCKS-Wall Street ends higher as Powell wraps up testimony'],
#  ['ACN',
#   'Jun-22-23',
#   '04:30PM',
#   'Accenture Tops Sales, Earnings Targets But New Bookings, Revenue Outlook Fall Short'],
#  ['ACN',
#   'Jun-22-23',
#   '02:23PM',
#   'US STOCKS-Nasdaq, S&P 500 gain as Powell wraps up testimony'],
#  ['ACN',
#   'Jun-22-23',
#   '12:55PM',
#   'US STOCKS-S&P 500, Dow pause as Powell defends inflation fight'],
#  ['ACN',
#   'Jun-22-23',
#   '12:10PM',
#   'Avid Bioservices, Accenture fall; Logitech, Steelcase rise, Thursday, 6/22/2023'],
#  ['ACN',
#   'Jun-22-23',
#   '11:47AM',
#   'Accenture stock falls after revenue forecast miss'],
#  ['ACN',
#   'Jun-22-23',
#   '11:38AM',
#   'Stocks to Watch Thursday: NRG, Darden, Paramount Global, Accenture'],
#  ['ACN', 'Jun-22-23', '10:48AM', 'Why Accenture Stock Was Down on Thursday'],
#  ['ACN',
#   'Jun-22-23',
#   '10:34AM',
#   'Accentures Earnings and Revenue Beat Estimates. Why the Stock Is Tumbling.'],
#  ['ACN',
#   'Jun-22-23',
#   '10:18AM',
#   "Accenture Pulls Back After Earnings Beat: Here's Our Strategy"],
#  ['ACN',
#   'Jun-22-23',
#   '09:42AM',
#   'Accenture (ACN) Surpasses Q3 Earnings Estimates, Rises Y/Y'],
#  ['ACN',
#   'Jun-22-23',
#   '09:20AM',
#   'What These 2 Stocks Are Saying About an Economic Slowdown'],
#  ['ACN',
#   'Jun-22-23',
#   '08:05AM',
#   'Accenture (ACN) Beats Q3 Earnings and Revenue Estimates'],
#  ['ACN',
#   'Jun-22-23',
#   '08:00AM',
#   'Why diverse leaders are the right CEOs for the A.I. era, according to Accentures Julie Sweet'],
#  ['ACN',
#   'Jun-22-23',
#   '07:52AM',
#   "US STOCKS-Futures fall on Powell's hawkish view on interest rate hikes"],
#  ['ACN', 'Jun-22-23', '06:58AM', 'Accenture: Fiscal Q3 Earnings Snapshot'],
#  ['ACN',
#   'Jun-22-23',
#   '06:58AM',
#   'Accenture signals more pain for IT industry with disappointing forecast'],
#  ['ACN',
#   'Jun-22-23',
#   '06:52AM',
#   "UPDATE 2-Accenture's revenue forecast disappoints as IT spending weakness persists"],
#  ['ACN',
#   'Jun-22-23',
#   '06:46AM',
#   'Accenture forecasts fourth-quarter revenue below estimates'],
#  ['ACN',
#   'Jun-22-23',
#   '06:44AM',
#   'Accenture Reports Strong Third-Quarter Fiscal 2023 Results'],
#  ['ACN',
#   'Jun-22-23',
#   '04:14AM',
#   'Stock Futures Fall as Powells Testimony Fuels Market Pullback'],
#  ['ACN',
#   'Jun-21-23',
#   '02:59PM',
#   'Accenture and Microsoft Expand Collaboration to Help Organizations Accelerate Responsible Adoption of Generative AI'],
#  ['ACN',
#   'Jun-21-23',
#   '02:59PM',
#   'Accenture and Google Cloud Help Organizations Scale Advances in Generative AI'],
#  ['ACN',
#   'Jun-21-23',
#   '02:59PM',
#   'Accenture and AWS Extend Generative AI Capabilities to Accelerate Adoption and Value'],
#  ['ACN',
#   'Jun-21-23',
#   '02:22PM',
#   "Accenture (ACN) Rises 25% in Three Months: Here's What to Know"],
#  ['ACN',
#   'Jun-21-23',
#   '12:27PM',
#   "Sterling Investment Partners Announces Sale of Anser Advisory to Accenture and Spinoff of Markon, Anser's Federal Consulting Business"],
#  ['ACN',
#   'Jun-21-23',
#   '11:39AM',
#   'Accenture to Acquire Anser Advisory to Expand Capital Project Capabilities'],
#  ['ACN',
#   'Jun-20-23',
#   '10:13AM',
#   'The 2 Must-Watch Stocks for Smart Investors This Week'],
#  ['ACN',
#   'Jun-20-23',
#   '07:59AM',
#   'Accenture Invests in Parfin to Build Responsible, Compliant Web3 Infrastructure for Financial Institutions'],
#  ['ACN',
#   'Jun-18-23',
#   '08:00AM',
#   "Here's Why We Think Accenture (NYSE:ACN) Is Well Worth Watching"],
#  ['ACN',
#   'Jun-16-23',
#   '05:43PM',
#   'Investors Stock Market Action Plan: Air Show, FedEx, Accenture And Powell'],
#  ['ACN',
#   'Jun-16-23',
#   '11:43AM',
#   'Top 20 Most Profitable Tech Companies in the World'],
#  ['ACN',
#   'Jun-15-23',
#   '06:59PM',
#   'Why Accenture Stock Topped the Market on Thursday'],
#  ['ACN',
#   'Jun-15-23',
#   '05:03PM',
#   'Accenture to invest $3 billion in AI over 3 years'],
#  ['ACN',
#   'Jun-15-23',
#   '12:58PM',
#   "Here's What to Expect From Accenture's (ACN) Q3 Earnings"],
#  ['ACN',
#   'Jun-15-23',
#   '10:00AM',
#   "Accenture (ACN) Earnings Expected to Grow: What to Know Ahead of Next Week's Release"],
#  ['ACN',
#   'Jun-15-23',
#   '07:59AM',
#   'Accenture Invests in Virtual Reality-Based, Diversity and Inclusion Learning Platform Praxis Labs'],
#  ['ACN',
#   'Jun-15-23',
#   '07:00AM',
#   'AI Stocks: AMD, Accenture, Salesforce Making Waves In Artificial Intelligence'],
#  ['ACN',
#   'Jun-15-23',
#   '05:50AM',
#   'McKinsey Says Artificial Intelligence (AI) Could Add $4.4 Trillion to the Global Economy'],
#  ['ACN',
#   'Jun-15-23',
#   '04:03AM',
#   "Lennar, JD.com, Domino's Pizza rise premarket; Tesla falls"],
#  ['ACN',
#   'Jun-15-23',
#   '12:55AM',
#   '4 big analyst picks: Accenture scores upgrade at Piper Sandler'],
#  ['ACN',
#   'Jun-13-23',
#   '02:18PM',
#   'Accenture pouring $3 billion into AI, joining long list of tech companies prepping to meet demand'],
#  ['ACN',
#   'Jun-13-23',
#   '11:14AM',
#   "Accenture Stock Is Breaking Out. Here's How High It Can Go."],
#  ['ACN',
#   'Jun-13-23',
#   '08:39AM',
#   'Accenture looks to power AI efforts with $3 billion investment'],
#  ['ACN',
#   'Jun-13-23',
#   '08:33AM',
#   'Accenture looks to power AI efforts with $3 billion investment'],
#  ['ACN',
#   'Jun-13-23',
#   '07:59AM',
#   'Aligning Cybersecurity to Business Objectives Helps Drive Revenue Growth and Lower Costs of Breaches, Accenture Report Finds'],
#  ['ACN',
#   'Jun-13-23',
#   '06:44AM',
#   'Accenture to Invest $3 Billion in AI to Accelerate Clients Reinvention'],
#  ['ACN',
#   'Jun-12-23',
#   '06:00PM',
#   'Accenture (ACN) Gains But Lags Market: What You Should Know'],
#  ['ACN',
#   'Jun-12-23',
#   '09:41AM',
#   "Adobe (ADBE) to Post Q2 Earning: What's in the Offing?"],
#  ['ACN',
#   'Jun-12-23',
#   '12:01AM',
#   'Companies rethink consultants as they fret about economic outlook'],
#  ['ACN',
#   'Jun-09-23',
#   '09:00AM',
#   'With 77% institutional ownership, Accenture plc (NYSE:ACN) is a favorite amongst the big guns'],
#  ['ACN',
#   'Jun-08-23',
#   '02:01PM',
#   'Google Contract Staff That Helped Train AI Seek To Unionize'],
#  ['ACN',
#   'Jun-07-23',
#   '05:00AM',
#   'Immersive Labs and Accenture Collaborate to Solve the Global Cyber Talent Shortage'],
#  ['ACN',
#   'Jun-06-23',
#   '05:50PM',
#   'Accenture (ACN) Outpaces Stock Market Gains: What You Should Know'],
#  ['ACN',
#   'Jun-06-23',
#   '12:10PM',
#   'Why Accenture (ACN) is Poised to Beat Earnings Estimates Again'],
#  ['ACN',
#   'Jun-06-23',
#   '11:07AM',
#   'The Zacks Analyst Blog Highlights Meta, Boeing, IBM, Accenture and Anheuser-Busch'],
#  ['ACN',
#   'Jun-06-23',
#   '09:00AM',
#   'Why Investors Need to Take Advantage of These 2 Business Services Stocks Now'],
#  ['ACN',
#   'Jun-06-23',
#   '08:59AM',
#   'Accenture Federal Services Wins $329 Million USAID Enterprise Information Assurance Contract'],
#  ['ACN',
#   'Jun-06-23',
#   '08:00AM',
#   '10 International Stocks Billionaires Are Loading Up On'],
#  ['ACN',
#   'Jun-06-23',
#   '06:59AM',
#   'Accenture to Announce Third-Quarter Fiscal 2023 Results'],
#  ['ACN',
#   'Jun-05-23',
#   '01:19PM',
#   'Top Stock Reports for Meta Platforms, Boeing & IBM'],
#  ['ACN',
#   'Jun-05-23',
#   '09:00AM',
#   'Does This Valuation Of Accenture plc (NYSE:ACN) Imply Investors Are Overpaying?'],
#  ['ACN',
#   'Jun-05-23',
#   '05:30AM',
#   'This Stock Will Be Critical in AI Integration for Thousands of Businesses'],
#  ['ACN',
#   'Jun-02-23',
#   '10:37AM',
#   'Accenture (ACN) Snaps Up Nextira, Bolsters Cloud Capabilities'],
#  ['ACN',
#   'Jun-01-23',
#   '11:10AM',
#   'Accenture Acquires Nextira, Expanding Engineering Capabilities in Artificial Intelligence and Machine Learning'],
#  ['ACN',
#   'Jun-01-23',
#   '11:05AM',
#   'Accenture (ACN) Announces Acquisition of Bourne Digital'],
#  ['ACN',
#   'Jun-01-23',
#   '10:00AM',
#   "Accenture's (NYSE:ACN) 15% CAGR outpaced the company's earnings growth over the same five-year period"],
#  ['ACN',
#   'Jun-01-23',
#   '07:58AM',
#   'Accenture Forms a Bottom With Strengthening Indicators'],
#  ['ACN',
#   'May-31-23',
#   '08:11PM',
#   'Accenture Acquires Bourne Digital, Expanding SAP Digital Design Capabilities in Australia'],
#  ['ACN',
#   'May-30-23',
#   '05:50PM',
#   'Accenture (ACN) Stock Moves 1.59%: What You Should Know'],
#  ['ACN',
#   'May-30-23',
#   '09:49AM',
#   'Accenture (ACN) Announces Its Plan to Snap Up Green Domus'],
#  ['ACN',
#   'May-30-23',
#   '06:49AM',
#   'The Zacks Analyst Blog Highlights Apple, Chevron, Accenture, Broadcom and Stryker'],
#  ['ACN',
#   'May-29-23',
#   '08:19AM',
#   'Accenture Announces Intent to Acquire Green Domus to Expand Sustainability Services Capabilities'],
#  ['ACN',
#   'May-26-23',
#   '04:17PM',
#   'Top Analyst Reports for Apple, Chevron & Accenture'],
#  ['ACN',
#   'May-26-23',
#   '11:08AM',
#   'Accenture Stock Moves Higher Along With Rising Relative Strength'],
#  ['ACN',
#   'May-26-23',
#   '09:30AM',
#   'Wall Street Analysts See Accenture (ACN) as a Buy: Should You Invest?'],
#  ['ADBE',
#   'Jul-13-23',
#   '02:00PM',
#   '3 Incredible Stocks Trading at Historical Discounts'],
#  ['ADBE',
#   'Jul-13-23',
#   '11:33AM',
#   "Adobe's $20B Figma Deal: UK Competition Watchdog Launches In-Depth Investigation"],
#  ['ADBE',
#   'Jul-13-23',
#   '11:20AM',
#   "UPDATE 1-Amazon's 'biggest ever' Prime Day boosts US online sales to $12.7 bln"],
#  ['ADBE',
#   'Jul-13-23',
#   '10:49AM',
#   'Amazon Prime Day Drives All Online Sales Up 6.1%, Missing Estimate'],
#  ['ADBE',
#   'Jul-13-23',
#   '09:00AM',
#   'Adobe Inc. (ADBE) is Attracting Investor Attention: Here is What You Should Know'],
#  ['ADBE',
#   'Jul-13-23',
#   '07:00AM',
#   'Adobe (NASDAQ:ADBE) Knows How To Allocate Capital Effectively'],
#  ['ADBE',
#   'Jul-13-23',
#   '04:56AM',
#   "UPDATE 2-UK announces in-depth probe of Adobe's $20 bln Figma deal"],
#  ['ADBE',
#   'Jul-13-23',
#   '04:36AM',
#   "UK regulator refers Adobe's $20 bln buyout of Figma to phase 2 probe"],
#  ['ADBE',
#   'Jul-12-23',
#   '04:07PM',
#   'Adobe Expands Generative AI Tool To Over 100 Languages'],
#  ['ADBE', 'Jul-12-23', '03:58PM', '25 Most Owned Stocks by Hedge Funds'],
#  ['ADBE',
#   'Jul-12-23',
#   '12:45PM',
#   'Adobe (ADBE) is an Incredible Growth Stock: 3 Reasons Why'],
#  ['ADBE',
#   'Jul-12-23',
#   '10:45AM',
#   'AI Stocks: Tech Giants, Cloud Titans, Chipmakers Battle For An Edge'],
#  ['ADBE',
#   'Jul-12-23',
#   '09:40AM',
#   'Is Adobe (ADBE) Outperforming Other Computer and Technology Stocks This Year?'],
#  ['ADBE',
#   'Jul-12-23',
#   '09:30AM',
#   'Wall Street Bulls Look Optimistic About Adobe (ADBE): Should You Buy?'],
#  ['ADBE',
#   'Jul-12-23',
#   '09:00AM',
#   'Adobe Firefly Expands Globally, Supports Prompts in Over 100 Languages'],
#  ['ADBE',
#   'Jul-12-23',
#   '09:00AM',
#   'Adobe Adds More Than 100 Languages to Firefly AI ToolsIncluding Klingon'],
#  ['ADBE',
#   'Jul-12-23',
#   '07:39AM',
#   'AI Drives the First-Half 2023 Stock Market'],
#  ['ADBE',
#   'Jul-11-23',
#   '08:53AM',
#   '10 Generative AI Stocks To Watch Amidst Copyright Concerns'],
#  ['ADBE',
#   'Jul-10-23',
#   '05:17PM',
#   'Sarah Silvermans ChatGPT Lawsuit Raises Big Questions for AI'],
#  ['ADBE',
#   'Jul-10-23',
#   '04:50PM',
#   'Sarah Silverman Sues OpenAI and Meta, Alleging Copyright Infringement'],
#  ['ADBE',
#   'Jul-10-23',
#   '03:37AM',
#   'Heres Why ClearBridge Large Cap Growth Strategy Increased its Position in Adobe (ADBE)'],
#  ['ADBE',
#   'Jul-07-23',
#   '01:38PM',
#   "Adobe Stock Today: This Calendar Spread Limits Risk While Upside Profit Is Infinite; Here's Why"],
#  ['ADBE',
#   'Jul-07-23',
#   '09:49AM',
#   'The Zacks Analyst Blog Highlights Mastercard, Oracle, Adobe, Accenture and Qualcomm'],
#  ['ADBE',
#   'Jul-07-23',
#   '08:30AM',
#   "Here's How Much You'd Have If You Invested $1000 in Adobe Systems a Decade Ago"],
#  ['ADBE', 'Jul-07-23', '05:49AM', '25 Best Work from Home Jobs for 2023'],
#  ['ADBE',
#   'Jul-06-23',
#   '04:50PM',
#   'Adobe, IBD Stock Of The Day, Looks To Monetize Generative AI'],
#  ['ADBE',
#   'Jul-06-23',
#   '11:57AM',
#   'Top Stock Reports for Mastercard, Oracle & Adobe'],
#  ['ADBE', 'Jul-06-23', '11:24AM', '12 Best Major Stocks to Buy Now'],
#  ['ADBE',
#   'Jul-05-23',
#   '09:28AM',
#   "Salesforce (CRM) Surges 60% YTD: What's Behind This Rally?"],
#  ['ADBE',
#   'Jul-05-23',
#   '09:05AM',
#   'Software Stocks To Watch Amid AI-Generated Rally'],
#  ['ADBE',
#   'Jul-05-23',
#   '07:51AM',
#   '5 Bigwigs to Watch With ESG Initiatives for Long-Term Gains'],
#  ['ADBE', 'Jul-04-23', '06:45PM', "Why Adobe's Stock Jumped 17% in June"],
# ...
#   'Down 30%, Is American Tower a Buy Right Now?'],
#  ['AMT',
#   'May-04-23',
#   '07:45AM',
#   "Why I Just Couldn't Resist Buying More of This Magnificent Dividend Stock"],
#  ['AMT', 'May-03-23', '07:21AM', 'Analyst Report: American Tower Corp.'],
#  ['AMT',
#   'May-03-23',
#   '07:06AM',
#   'Market Digest: CB, AMT, GD, ITW, MAR, NOC, ROP, XOM, NOW, QSR'],
#  ['AMT',
#   'May-02-23',
#   '09:42AM',
#   "SBA Communications (SBAC) Beats on Q1 FFO, Raises '23 View"],
#  ['AMT',
#   'May-02-23',
#   '09:35AM',
#   'This 3.1%-Yielding Dividend Stock Has Enormous Growth Ahead'],
#  ['AMT',
#   'May-02-23',
#   '09:01AM',
#   '15 Best Income Stocks to Buy According to Analysts'],
#  ['AMT',
#   'Apr-28-23',
#   '08:06AM',
#   'Digital Realty (DLR) Q1 FFO Beats, Revenues Increase Y/Y'],
#  ['AMT',
#   'Apr-28-23',
#   '03:53AM',
#   '15 Major Cities That Have the Cheapest Rent in the U.S.'],
#  ['AMT',
#   'Apr-27-23',
#   '07:30AM',
#   'Down Nearly 30%, This Elite Dividend Stock Appears Poised to Rally'],
#  ['AMT', 'Apr-27-23', '02:04AM', 'Q1 2023 American Tower Corp Earnings Call'],
#  ['AMT', 'Apr-26-23', '09:11PM', 'Analyst Report: American Tower Corporation'],
#  ['AMT',
#   'Apr-26-23',
#   '01:23PM',
#   'American Tower Beats Street Topline View, Organic Tenant Billings See Growth'],
#  ['AMT',
#   'Apr-26-23',
#   '10:08AM',
#   "American Tower (AMT) Q1 AFFO & Revenues Top, '23 View Revised"],
#  ['AMT',
#   'Apr-26-23',
#   '09:30AM',
#   'American Tower (AMT) Q1 Earnings: Taking a Look at Key Metrics Versus Estimates'],
#  ['AMT',
#   'Apr-26-23',
#   '08:15AM',
#   'American Tower (AMT) Q1 FFO and Revenues Top Estimates'],
#  ['AMT', 'Apr-26-23', '07:10AM', 'American Tower: Q1 Earnings Snapshot'],
#  ['AMT',
#   'Apr-26-23',
#   '07:00AM',
#   'American Tower Corporation Reports First Quarter 2023 Financial Results'],
#  ['AMT', 'Apr-25-23', '10:41AM', 'Is American Tower Stock a Buy?'],
#  ['AMT',
#   'Apr-25-23',
#   '08:55AM',
#   "Key Factors to Impact Medical Properties' (MPW) Q1 Earnings"],
#  ['AMT',
#   'Apr-25-23',
#   '08:32AM',
#   'Why Earnings Season Could Be Great for American Tower (AMT)'],
#  ['AMT',
#   'Apr-24-23',
#   '09:03AM',
#   'Is a Beat in Store for American Tower (AMT) in Q1 Earnings?'],
#  ['AMT', 'Apr-21-23', '10:13AM', '10 Best REIT Stocks Under $10'],
#  ['AMT',
#   'Apr-21-23',
#   '05:39AM',
#   "Before You Buy American Tower: Here's a REIT I'd Buy First"],
#  ['AMT', 'Apr-19-23', '06:25AM', '11 Best REIT Dividend Stocks'],
#  ['AMT',
#   'Apr-18-23',
#   '06:00PM',
#   'American Tower (AMT) Stock Sinks As Market Gains: What You Should Know'],
#  ['AMT',
#   'Apr-18-23',
#   '07:00AM',
#   'CoreSite Adds New Open Cloud Exchange® Automation and Direct-to-Cloud Capabilities with Oracle Cloud Infrastructure'],
#  ['AMT',
#   'Apr-17-23',
#   '11:30AM',
#   'Arcadian Transforms Digital Files Into Streamable Content with CoreSites Secure, Reliable Colocation Services'],
#  ['AMT', 'Apr-14-23', '06:38AM', '20 Biggest Real Estate Companies in USA'],
#  ['AMT',
#   'Apr-12-23',
#   '06:00PM',
#   'American Tower (AMT) Gains As Market Dips: What You Should Know'],
#  ['AMT',
#   'Apr-12-23',
#   '04:09AM',
#   'Broader REIT Sell-Off Impacted American Tower Corporation (AMT) in Q1'],
#  ['AMT',
#   'Apr-11-23',
#   '09:31AM',
#   "American Tower (AMT) Gains 13.4% in Past 6 Months: Here's Why"],
#  ['AMT',
#   'Apr-08-23',
#   '08:05AM',
#   'Adding $500 to These Stocks Would Be a Genius Move Right Now'],
#  ['AMT',
#   'Apr-07-23',
#   '04:30PM',
#   'American Tower Plans First Quarter 2023 Earnings Release and Conference Call'],
#  ['AMT', 'Apr-07-23', '11:14AM', '10 Cheap REITs with Huge Upside'],
#  ['AMT',
#   'Apr-07-23',
#   '11:00AM',
#   '14 Stocks About To Pop According To Jim Cramer: In Retrospect'],
#  ['AMT',
#   'Apr-07-23',
#   '10:07AM',
#   'Credit Suisses 12 Highest-Conviction Top Picks'],
#  ['AMT', 'Apr-07-23', '05:03AM', '3 Top REITs to Buy in April'],
#  ['AMT',
#   'Apr-06-23',
#   '06:15PM',
#   'American Tower (AMT) Outpaces Stock Market Gains: What You Should Know'],
#  ['AMT', 'Apr-06-23', '02:27PM', '3 High-Yield REITs to Buy Now'],
#  ['AMT', 'Apr-06-23', '06:56AM', '3 Top Dividend Stocks to Buy in April'],
#  ['AMT',
#   'Apr-01-23',
#   '07:46AM',
#   '3 Dirt-Cheap Dividend Stocks to Buy in April'],
#  ['AMT',
#   'Mar-31-23',
#   '06:00PM',
#   'American Tower (AMT) Outpaces Stock Market Gains: What You Should Know'],
#  ['AMT',
#   'Mar-29-23',
#   '09:41AM',
#   'These 4 Top Dividend Stocks Have 22% to 47% Upside Potential, According to Wall Street'],
#  ['AMT',
#   'Mar-28-23',
#   '06:15PM',
#   'American Tower (AMT) Stock Moves -0.14%: What You Should Know'],
#  ['AMT',
#   'Mar-27-23',
#   '02:33PM',
#   "If You Invested $10K In American Tower 5 years Ago, Here's How Much You Would Be Making In Dividends Today"],
#  ['AMT',
#   'Mar-26-23',
#   '07:09AM',
#   "Now's the Time to Count On These 3 Solid Dividend Stocks"],
#  ['AMT',
#   'Mar-24-23',
#   '11:02AM',
#   'Is American Tower (AMT) an Apt Choice for Your Portfolio Now?'],
#  ['AMT',
#   'Mar-22-23',
#   '01:33PM',
#   'Top Stock Reports for Amazon.com, Novo Nordisk & QUALCOMM'],
#  ['AMT',
#   'Mar-21-23',
#   '06:00PM',
#   'American Tower (AMT) Stock Sinks As Market Gains: What You Should Know'],
#  ['AMT',
#   'Mar-19-23',
#   '07:45AM',
#   '3 Reliable Dividend Stocks to Diversify Your Portfolio'],
#  ['AMZN',
#   'Jul-14-23',
#   '09:07AM',
#   'Amazon Fuel Cell Supplier Rallies On Upgrade, Back-To-Back Deals'],
#  ['AMZN',
#   'Jul-14-23',
#   '07:30AM',
#   'Amazon partner airline ASL cuts 28 European contract pilots'],
#  ['AMZN', 'Jul-14-23', '07:27AM', '5 Things to Know Before Markets Open'],
#  ['AMZN',
#   'Jul-14-23',
#   '06:20AM',
#   'Amazon has become one the most boring stories in tech: Morning Brief'],
#  ['AMZN',
#   'Jul-14-23',
#   '06:14AM',
#   "If I Could Only Buy 5 Stocks, Here's What They Would Be"],
#  ['AMZN',
#   'Jul-14-23',
#   '06:11AM',
#   'Medallion Fund Strategy, Returns, and Holdings'],
#  ['AMZN',
#   'Jul-14-23',
#   '05:50AM',
#   '3 Best Buffett Stocks to Buy for the Long Haul'],
#  ['AMZN', 'Jul-14-23', '05:09AM', 'AMD Stock: Bear vs. Bull'],
#  ['AMZN',
#   'Jul-14-23',
#   '05:02AM',
#   '3 Growth Stocks That Shine on the Bottom Line'],
#  ['AMZN', 'Jul-13-23', '07:14PM', 'The 2023 Unhedged stock draft'],
#  ['AMZN', 'Jul-13-23', '07:05PM', 'Should You Hold a Stock for Forever?'],
#  ['AMZN',
#   'Jul-13-23',
#   '05:15PM',
#   'FTC investigating ChatGPT-maker OpenAI over consumer protection concerns'],
#  ['AMZN',
#   'Jul-13-23',
#   '04:31PM',
#   'Progressive earnings, Amazon Prime Day, Perrigo birth control: Top stories'],
#  ['AMZN',
#   'Jul-13-23',
#   '04:29PM',
#   "Which Companies Could Buy a Stake in Disney's ESPN?"],
#  ['AMZN',
#   'Jul-13-23',
#   '02:55PM',
#   'Architect of US tech crackdown faces Republican critics'],
#  ['AMZN',
#   'Jul-13-23',
#   '02:40PM',
#   'Amazon Stock Is Rising. Sales Hit a Record During Prime Day.'],
#  ['AMZN',
#   'Jul-13-23',
#   '02:06PM',
#   'Billionaire David Teppers Investment Strategy and 10 Favorite Stocks'],
#  ['AMZN',
#   'Jul-13-23',
#   '01:13PM',
#   'Amazon Has Biggest Single-Day Sales Ever During Prime Day Despite Inflation'],
#  ['AMZN',
#   'Jul-13-23',
#   '12:13PM',
#   'Stock market today: Dow rides tech higher ahead of earnings from major banks'],
#  ['AMZN',
#   'Jul-13-23',
#   '12:01PM',
#   'Larry Robbins Net Worth, Performance and Portfolio'],
#  ['AMZN',
#   'Jul-13-23',
#   '11:55AM',
#   'US Labor Board Slaps Complaint On Amazon For Bargaining Anomalies'],
#  ['AMZN',
#   'Jul-13-23',
#   '11:52AM',
#   'Top 15 Big Data Analytics Companies of 2023'],
#  ['AMZN',
#   'Jul-13-23',
#   '11:20AM',
#   "UPDATE 1-Amazon's 'biggest ever' Prime Day boosts US online sales to $12.7 bln"],
#  ['AMZN',
#   'Jul-13-23',
#   '11:15AM',
#   'Amazon Stock Is Rising. Sales Hit a Record During Prime Day.'],
#  ['AMZN',
#   'Jul-13-23',
#   '10:49AM',
#   'Amazon Prime Day Drives All Online Sales Up 6.1%, Missing Estimate'],
#  ['AMZN',
#   'Jul-13-23',
#   '10:46AM',
#   'Amazon said it had its biggest Prime day event ever this year'],
#  ['AMZN',
#   'Jul-13-23',
#   '10:40AM',
#   '1 AI Stock Up More Than 50% This Year That Shows No Signs of Stopping Anytime Soon'],
#  ['AMZN',
#   'Jul-13-23',
#   '09:43AM',
#   "Amazon's 'biggest ever' Prime Day boosts US online sales to $12.7 billion"],
#  ['AMZN',
#   'Jul-13-23',
#   '09:40AM',
#   "US online sales in Amazon's Prime Day rise to $12.7 bln - report"],
#  ['AMZN',
#   'Jul-13-23',
#   '09:00AM',
#   'First Day of Prime Day was the Single Largest Sales Day Ever on Amazon, Helping Make This the Biggest Prime Day Event Ever'],
#  ['AMZN',
#   'Jul-13-23',
#   '08:30AM',
#   'Better Artificial Intelligence Stock: Amazon vs. Microsoft'],
#  ['AMZN',
#   'Jul-13-23',
#   '08:01AM',
#   "National Safety Council Awards Nearly $275,000 to Nation's Top Innovators to Solve Most Common Workplace Injury"],
#  ['AMZN',
#   'Jul-13-23',
#   '08:00AM',
#   'At US$131, Is It Time To Put Amazon.com, Inc. (NASDAQ:AMZN) On Your Watch List?'],
#  ['AMZN',
#   'Jul-13-23',
#   '07:00AM',
#   'Will multi-robot orchestration platforms transform warehouse logistics?'],
#  ['AMZN', 'Jul-13-23', '07:00AM', '2 Top Stocks to Buy in July'],
#  ['AMZN',
#   'Jul-13-23',
#   '01:26AM',
#   'UPDATE 2-Amazon gets labor board complaint on failure to bargain with NY union'],
#  ['AMZN',
#   'Jul-12-23',
#   '11:28PM',
#   'Amazon faces labor complaint over failure to bargain with union'],
#  ['AMZN',
#   'Jul-12-23',
#   '07:07PM',
#   'Warren Calls on\xa0Fed to Halt Interest Rate Hikes as Inflation Eases'],
#  ['AMZN',
#   'Jul-12-23',
#   '04:02PM',
#   "Amazon Prime Day sales may be 'last gasp of a beleaguered consumer,' says strategist"],
#  ['AMZN', 'Jul-12-23', '03:58PM', '25 Most Owned Stocks by Hedge Funds'],
#  ['AMZN',
#   'Jul-12-23',
#   '01:25PM',
#   "Amazon's Prime Day Is Off to a Strong Start: Here's Our Take on the Numbers"],
#  ['AMZN',
#   'Jul-12-23',
#   '01:12PM',
#   'Prime Day Is Off to a Strong Start. Consumers Are Bargain Hunting.'],
#  ['AMZN', 'Jul-12-23', '12:18PM', '20 Most Hated Brands in the World'],
#  ['AMZN',
#   'Jul-12-23',
#   '11:09AM',
#   'Back-to-school spending set for first drop in nine years due to inflation'],
#  ['AMZN',
#   'Jul-12-23',
#   '11:08AM',
#   'Competitors Work To Keep Up With Amazons Summer Sales Growth'],
#  ['AMZN',
#   'Jul-12-23',
#   '11:04AM',
#   'UPDATE 2-Amazon Prime Day sales rise as deep discounts tempt inflation-hit shoppers'],
#  ['AMZN',
#   'Jul-12-23',
#   '10:48AM',
#   'Should Microsoft, Alphabet, and Amazon Stock Investors Be Worried About Cloud AI Restrictions for China?'],
#  ['AMZN',
#   'Jul-12-23',
#   '10:44AM',
#   'HIGHLIGHTS: Anti-Woke Marketplace Goes Public  Fireside with PublicSq. CEO'],
#  ['AMZN',
#   'Jul-12-23',
#   '10:15AM',
#   '2 Unstoppable Stocks That Could Join Apple, Microsoft, Nvidia, Amazon, and Alphabet in the $1 Trillion Club'],
#  ['AMZN',
#   'Jul-12-23',
#   '10:10AM',
#   'Amazon Prime Day sales rise as deep discounts tempt inflation-hit shoppers'],
#  ['AMZN',
#   'Jul-12-23',
#   '10:02AM',
#   'Amazon Prime Day sales rise as deep discounts tempt inflation-hit customers'],
#  ['AMZN', 'Jul-12-23', '09:38AM', 'Company News for Jul 12, 2023'],
#  ['AMZN',
#   'Jul-12-23',
#   '08:49AM',
#   '10 Cloud Computing Stocks to Watch As AI Arms Race Is Underway'],
#  ['AMZN', 'Jul-12-23', '08:30AM', 'Better Buy: AMD vs. Apple'],
#  ['AMZN',
#   'Jul-12-23',
#   '08:00AM',
#   'Could DigitalOcean Become the Next Amazon?'],
#  ['AMZN', 'Jul-12-23', '07:59AM', 'Is Amazon a Buy Now?'],
#  ['AMZN',
#   'Jul-12-23',
#   '06:30AM',
#   'Kids and Grownup Gamers Will Love This Amazon Prime Perk'],
#  ['AMZN', 'Jul-12-23', '05:33AM', 'Rivian Stock: Bull vs. Bear'],
#  ['AMZN',
#   'Jul-12-23',
#   '05:25AM',
#   '2 Stocks That Need to Eliminate Their Dividends, and 2 That Should Offer Payouts'],
#  ['AMZN',
#   'Jul-12-23',
#   '05:12AM',
#   '3 Things About Amazon That Smart Investors Know'],
#  ['AMZN',
#   'Jul-12-23',
#   '04:45AM',
#   "This Stock Market Indicator Has Been Right 82% of the Time Since 1945. Here's What It Says Now."],
#  ['AMZN',
#   'Jul-11-23',
#   '08:11PM',
#   'Amazon touts its low-cost cloud computing in generative AI race'],
#  ['AMZN',
#   'Jul-11-23',
#   '08:08PM',
#   'REUTERS MOMENTUM-Amazon touts its low-cost cloud computing in generative AI race'],
#  ['AMZN', 'Jul-11-23', '07:00PM', '7 Items That Are Always Cheaper on Amazon'],
#  ['AMZN',
#   'Jul-11-23',
#   '06:09PM',
#   'Amazon Sued for Allegedly Deceptive Practices Across Prime, Audible'],
#  ['AMZN', 'Jul-11-23', '05:59PM', 'Amazons Prime Day Tests Consumer Demand'],
#  ['AMZN',
#   'Jul-11-23',
#   '05:57PM',
#   'Why Verizon Stock Fell 6% in the First Half of the Year'],
#  ['AMZN',
#   'Jul-11-23',
#   '05:45PM',
#   'Amazon (AMZN) Outpaces Stock Market Gains: What You Should Know'],
#  ['AMZN',
#   'Jul-11-23',
#   '04:35PM',
#   "UPDATE 1-US lawmakers question Techtronic's Milwaukee Tool on alleged links to forced labor"],
#  ['AMZN',
#   'Jul-11-23',
#   '04:15PM',
#   'Amazon Celebrates Prime Day With Bullish Wall Street Ratings'],
#  ['AMZN',
#   'Jul-11-23',
#   '04:15PM',
#   'Stock Market Today: Markets Rise Ahead of CPI; Activision, Amazon Stocks Outperform'],
#  ['AMZN',
#   'Jul-11-23',
#   '04:08PM',
#   "UPDATE 1-Amazon dangles deeper 'Prime Day' discounts for stressed US shoppers"],
#  ['AMZN',
#   'Jul-11-23',
#   '04:07PM',
#   'UPDATE 1-Amazon workers sue NYC union to force leadership vote'],
#  ['AMZN',
#   'Jul-11-23',
#   '03:47PM',
#   "Amazon Prime Day sales could be 'last gasp of a beleaguered consumer': Strategist"],
#  ['AMZN',
#   'Jul-11-23',
#   '03:04PM',
#   'Should I Cancel Amazon Prime? Here Are 12 Good Reasons'],
#  ['AMZN',
#   'Jul-11-23',
#   '02:07PM',
#   'Bipartisan lawmakers question Milwaukee Tool on alleged forced labor in supply chain'],
#  ['AMZN',
#   'Jul-11-23',
#   '01:48PM',
#   'Stocks to Watch Tuesday: Salesforce, Activision, Amazon, Newell Brands'],
#  ['AMZN',
#   'Jul-11-23',
#   '01:18PM',
#   'Amazon Stock Has Gained 50%. Why Theres Still Time to Buy.'],
#  ['AMZN',
#   'Jul-11-23',
#   '01:01PM',
#   'Markets Up Midday With Inflation Data and Earnings Reports in Focus'],
#  ['AMZN',
#   'Jul-11-23',
#   '12:53PM',
#   'Amazon Can Help You Save On Travel This Prime Day'],
#  ['AMZN',
#   'Jul-11-23',
#   '12:49PM',
#   "Amazon Challenges its Designation Under EU's Online Hate Speech Rules"],
#  ['AMZN',
#   'Jul-11-23',
#   '12:48PM',
#   'These Stocks Are Moving the Most Today: Activision, Amazon, WD-40, Affirm, Shutterstock, and More'],
#  ['AMZN',
#   'Jul-11-23',
#   '12:39PM',
#   "Nasdaq 100 to rebalance due to 'magnificent seven' dominance"],
#  ['AMZN',
#   'Jul-11-23',
#   '12:14PM',
#   'Amazon Prime Day Invite-Only Deal Targets Buyer Frustration'],
#  ['AMZN',
#   'Jul-11-23',
#   '11:53AM',
#   'Amazon Prime Day: How robots are helping ship out orders'],
#  ['AMZN',
#   'Jul-11-23',
#   '11:34AM',
#   "Amazon pushes back against Europe's pioneering new digital rules"],
#  ['AMZN',
#   'Jul-11-23',
#   '11:27AM',
#   "Amazon Analysts Estimate Deeper Discounts On Prime Day, Meta Platforms Threads App Can Generate Annual Sales Of $8B In 2 years, Uber's CFO Departs: Today's Top Stories"],
#  ['AMZN',
#   'Jul-11-23',
#   '11:07AM',
#   "Amazon Prime Day: Why it's difficult for investors to determine how successful it is"],
#  ['AMZN',
#   'Jul-11-23',
#   '11:03AM',
#   'As Amazon Prime Day Kicks Off, Targets Troubles Remain'],
#  ['AMZN',
#   'Jul-11-23',
#   '11:01AM',
#   'Amazon labor union faction sues to force leadership election'],
#  ['AMZN',
#   'Jul-11-23',
#   '09:50AM',
#   "Consumer spending: Don't expect seismic shifts, strategist says"],
#  ['AMZN',
#   'Jul-11-23',
#   '09:47AM',
#   'Amazon Stock Is a Buy Into Earnings. Thats Only Half the Story.'],
#  ['AMZN',
#   'Jul-11-23',
#   '09:39AM',
#   'Amazon launches legal challenge of EUs unfair big tech rules'],
#  ['AMZN',
#   'Jul-11-23',
#   '09:30AM',
#   'Wall Street Bulls Look Optimistic About Amazon (AMZN): Should You Buy?'],
#  ['AMZN',
#   'Jul-11-23',
#   '09:29AM',
#   'Amazon Prime Day: What could be different for sales, stock this year'],
#  ['AMZN',
#   'Jul-11-23',
#   '09:26AM',
#   "Stocks brace for CPI data, Amazon Prime Day, Meta's Threads sign-ups: 3 Things"],
#  ['AMZN',
#   'Jul-11-23',
#   '09:00AM',
#   'Here is What to Know Beyond Why Amazon.com, Inc. (AMZN) is a Trending Stock'],
#  ['AMZN',
#   'Jul-11-23',
#   '09:00AM',
#   "We're Primed for June CPI Data as Amazon Prime Day Kicks Off"],
#  ['AMZN',
#   'Jul-11-23',
#   '08:53AM',
#   '10 Generative AI Stocks To Watch Amidst Copyright Concerns'],
#  ['AMZN',
#   'Jul-11-23',
#   '08:45AM',
#   'US STOCKS-Wall St set to open higher ahead of monthly inflation data'],
#  ...]

# %%
##### Perform Sentiment Analysis with Vader
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()
# Set column names
columns = ['ticker', 'date', 'time', 'headline']
# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()
# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')
# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date
parsed_and_scored_news.tail()
# Out:
#      ticker        date     time  \
# 9995    XOM  2023-06-16  07:40AM
# 9996    XOM  2023-06-16  07:08AM
# 9997    XOM  2023-06-16  07:00AM
# 9998    XOM  2023-06-16  07:00AM
# 9999    XOM  2023-06-15  07:09PM
#
#                                                headline    neg    neu   pos  \
# 9995  Oil faces a 'serious problem' by 2024 as produ...  0.197  0.803  0.00
# 9996  Inside the race to remake lithium extraction f...  0.000  1.000  0.00
# 9997  Investors in Exxon Mobil (NYSE:XOM) have seen ...  0.000  0.820  0.18
# 9998  INSIGHT-Inside the race to remake lithium extr...  0.000  1.000  0.00
# 9999   Tales of Stock Compounding: Does It Always Work?  0.000  1.000  0.00
#
#       compound
# 9995   -0.5267
# 9996    0.0000
# 9997    0.5106
# 9998    0.0000
# 9999    0.0000

# %%
# Group by each ticker and get the mean of all sentiment scores
mean_scores = parsed_and_scored_news.groupby(['ticker']).mean()
mean_scores
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16264\2723772882.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#             neg      neu      pos  compound
# ticker
# AAPL    0.03496  0.84100  0.12402  0.134145
# ABBV    0.03245  0.84974  0.11781  0.135030
# ABT     0.04561  0.86803  0.08636  0.061686
# ACN     0.02564  0.86268  0.11168  0.143406
# ADBE    0.04316  0.87446  0.08239  0.052778
# ...         ...      ...      ...       ...
# VZ      0.02482  0.86735  0.10782  0.141956
# WBA     0.09430  0.81435  0.09136  0.019264
# WFC     0.06189  0.75951  0.17859  0.161680
# WMT     0.03938  0.80769  0.15293  0.152200
# XOM     0.04880  0.82672  0.12449  0.118250
#
# [100 rows x 4 columns]

# %%
import yfinance as yf

# %%
# get the price, sector and industry of each ticker using the yahoo finance api
# as an example this is the information that the api returns for TSLA
tickerdata = yf.Ticker('TSLA')
tickerdata.info
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[147], line 4
#       1 # get the price, sector and industry of each ticker using the yahoo finance api
#       2 # as an example this is the information that the api returns for TSLA
#       3 tickerdata = yf.Ticker('TSLA')
# ----> 4 tickerdata.info
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\ticker.py:138, in Ticker.info(self)
#     136 @property
#     137 def info(self) -> dict:
# --> 138     return self.get_info()
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\base.py:1020, in TickerBase.get_info(self, proxy)
#    1018 def get_info(self, proxy=None) -> dict:
#    1019     self._quote.proxy = proxy
# -> 1020     data = self._quote.info
#    1021     return data
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\scrapers\quote.py:555, in Quote.info(self)
#     551 @property
#     552 def info(self) -> dict:
#     553     if self._info is None:
#     554         # self._scrape(self.proxy)  # decrypt broken
# --> 555         self._fetch(self.proxy)
#     557         self._fetch_complementary(self.proxy)
#     559     return self._info
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\scrapers\quote.py:706, in Quote._fetch(self, proxy)
#     703 self._already_fetched = True
#     704 modules = ['summaryProfile', 'financialData', 'quoteType',
#     705              'defaultKeyStatistics', 'assetProfile', 'summaryDetail']
# --> 706 result = self._data.get_raw_json(
#     707     _BASIC_URL_ + f"/{self._data.ticker}", params={"modules": ",".join(modules), "ssl": "true"}, proxy=proxy
#     708 )
#     709 result["quoteSummary"]["result"][0]["symbol"] = self._data.ticker
#     710 query1_info = next(
#     711     (info for info in result.get("quoteSummary", {}).get("result", []) if info["symbol"] == self._data.ticker),
#     712     None,
#     713 )
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\data.py:209, in TickerData.get_raw_json(self, url, user_agent_headers, params, proxy, timeout)
#     207 def get_raw_json(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#     208     response = self.get(url, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
# --> 209     response.raise_for_status()
#     210     return response.json()
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TSLA?modules=summaryProfile%2CfinancialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&ssl=true

# %%
import numpy as np

industries = []
sectors = []
prices = []
for ticker in tickers:
    tickerdata = yf.Ticker(ticker)
    try:
        prices.append(tickerdata.info['currentPrice'])
    except KeyError:
        prices.append(np.nan)

    try:
        sectors.append(tickerdata.info['sector'])
    except KeyError:
        sectors.append(np.nan)

    try:
        industries.append(tickerdata.info['industry'])
    except KeyError:
        industries.append(np.nan)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[122], line 9
#       7 tickerdata = yf.Ticker(ticker)
#       8 try:
# ----> 9     prices.append(tickerdata.info['currentPrice'])
#      10 except KeyError:
#      11     prices.append(np.nan)
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\ticker.py:138, in Ticker.info(self)
#     136 @property
#     137 def info(self) -> dict:
# --> 138     return self.get_info()
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\base.py:1020, in TickerBase.get_info(self, proxy)
#    1018 def get_info(self, proxy=None) -> dict:
#    1019     self._quote.proxy = proxy
# -> 1020     data = self._quote.info
#    1021     return data
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\scrapers\quote.py:555, in Quote.info(self)
#     551 @property
#     552 def info(self) -> dict:
#     553     if self._info is None:
#     554         # self._scrape(self.proxy)  # decrypt broken
# --> 555         self._fetch(self.proxy)
#     557         self._fetch_complementary(self.proxy)
#     559     return self._info
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\scrapers\quote.py:706, in Quote._fetch(self, proxy)
#     703 self._already_fetched = True
#     704 modules = ['summaryProfile', 'financialData', 'quoteType',
#     705              'defaultKeyStatistics', 'assetProfile', 'summaryDetail']
# --> 706 result = self._data.get_raw_json(
#     707     _BASIC_URL_ + f"/{self._data.ticker}", params={"modules": ",".join(modules), "ssl": "true"}, proxy=proxy
#     708 )
#     709 result["quoteSummary"]["result"][0]["symbol"] = self._data.ticker
#     710 query1_info = next(
#     711     (info for info in result.get("quoteSummary", {}).get("result", []) if info["symbol"] == self._data.ticker),
#     712     None,
#     713 )
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\yfinance\data.py:209, in TickerData.get_raw_json(self, url, user_agent_headers, params, proxy, timeout)
#     207 def get_raw_json(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#     208     response = self.get(url, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
# --> 209     response.raise_for_status()
#     210     return response.json()
#
# File c:\Users\Admin\anaconda3\envs\streamlit-app\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAPL?modules=summaryProfile%2CfinancialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&ssl=true

# %%
# dictionary {'column name': list of values for column} to be converted to dataframe
d = {'Sector': sectors, 'Industry': industries, 'Price': prices}
# create dataframe from 
df_info = pd.DataFrame(data=d, index=tickers)
df_info
# Out:
#                         Sector                         Industry    Price
# Symbol
# AAPL                Technology             Consumer Electronics  190.320
# ABBV                Healthcare       Drug Manufacturers—General  133.835
# ABT                 Healthcare                  Medical Devices  106.810
# ACN                 Technology  Information Technology Services  315.150
# ADBE                Technology          Software—Infrastructure  512.940
# ...                        ...                              ...      ...
# VZ      Communication Services                 Telecom Services   34.565
# WBA                 Healthcare         Pharmaceutical Retailers   29.890
# WFC         Financial Services                Banks—Diversified   43.455
# WMT         Consumer Defensive                  Discount Stores  154.430
# XOM                     Energy             Oil & Gas Integrated  104.000
#
# [100 rows x 3 columns]

# %%
df = mean_scores.join(df_info)
df = df.rename(columns={"compound": "Sentiment Score", "neg": "Negative", "neu": "Neutral", "pos": "Positive"})
df = df.reset_index()
df
# Out:
#    ticker  Negative  Neutral  Positive  Sentiment Score  \
# 0    AAPL   0.04388  0.84774   0.10836         0.086201
# 1    ABBV   0.03000  0.84824   0.12176         0.146174
# 2     ABT   0.04847  0.86294   0.08859         0.061468
# 3     ACN   0.02564  0.86268   0.11168         0.143406
# 4    ADBE   0.04145  0.87230   0.08625         0.064446
# ..    ...       ...      ...       ...              ...
# 95     VZ   0.02637  0.87088   0.10275         0.125678
# 96    WBA   0.09430  0.81435   0.09136         0.019264
# 97    WFC   0.07355  0.77450   0.15193         0.104411
# 98    WMT   0.04117  0.80796   0.15086         0.147280
# 99    XOM   0.05038  0.80983   0.13980         0.137952
#
#                     Sector                         Industry    Price
# 0               Technology             Consumer Electronics  190.320
# 1               Healthcare       Drug Manufacturers—General  133.835
# 2               Healthcare                  Medical Devices  106.810
# 3               Technology  Information Technology Services  315.150
# 4               Technology          Software—Infrastructure  512.940
# ..                     ...                              ...      ...
# 95  Communication Services                 Telecom Services   34.565
# 96              Healthcare         Pharmaceutical Retailers   29.890
# 97      Financial Services                Banks—Diversified   43.455
# 98      Consumer Defensive                  Discount Stores  154.430
# 99                  Energy             Oil & Gas Integrated  104.000
#
# [100 rows x 8 columns]

# %%
fig = px.treemap(df, path=[px.Constant("Sectors"), 'Sector', 'Industry', 'ticker'],
                  color='Sentiment Score', hover_data=['Price', 'Negative', 'Neutral', 'Positive', 'Sentiment Score'],
                  color_continuous_scale=['#FF0000', "#000000", '#00FF00'],
                  color_continuous_midpoint=0)

# %%
fig.data[0].customdata = df[['Price', 'Negative', 'Neutral', 'Positive', 'Sentiment Score']].round(3) # round to 3 decimal places
fig.data[0].texttemplate = "%{label}<br>%{customdata[4]}"

# %%
fig.update_traces(textposition="middle center")
fig.update_layout(margin = dict(t=30, l=10, r=10, b=10), font_size=20)

plotly.offline.plot(fig, filename='stock_sentiment.html') # this writes the plot into a html file and opens it
# Out:
# 'stock_sentiment.html'
